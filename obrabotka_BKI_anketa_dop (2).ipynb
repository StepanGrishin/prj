# %%
import pandas as pd
import numpy as np
import pickle
import json
#from category_encoders import CatBoostEncoder, WOEEncoder, OneHotEncoder

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# - [Обработка анкетных данных](#Обработка-анкетных-данных)
# - [Загрузка данных](##загрузка-данных)
# - [Обработка данных](##обработка-данных)
# - [Убираем хвосты](##убираем-хвосты)
# - [Энкодинг](##Энкодинг)
#
# - [Обработка БКИ](#Обработка-БКИ)

# %% [markdown]
# <a id='Обработка-анкетных-данных'></a>
# # Обработка анкетных данных

# %% [markdown]
# <a id='загрузка-данных'></a>
# ## Загрузка данных

# %%
# Ваш JSON файл
with open('Z:\\Скоринг –Олег\\Подготовка фичей\\jsons_test\\jsons_flag1\\00C7A306-7486-4B30-9363-05C230052198.json') as f:
    data = json.load(f)

# Нормализация JSON с помощью json_normalize
df = pd.json_normalize(data)
df.rename(columns=lambda x: x.split('.')[-1], inplace=True)

# %%
data = {"ScoringAmount":5900,"Score":500,"ActivityType":np.NaN,"Education":"\u0421\u0440\u0435\u0434\u043d\u0435\u0435","Gender":1,"LoanPurpose":np.NaN,"MaritalStatus":0,"MonthlyIncome":45000,"Post":"\u0420\u0430\u0431\u043e\u0447\u0438\u0439","OrganizationPhone":"+7 (391) 274-94-11","InsurancePolicy":1,"VerifiedByESIA":0,"EMailVerified":0,"RegisterSameFact":1,"StoreName":"website","mobile":0,"PingTreeLead":0,"Bin":220070,"Bank":np.NaN,"mask_person_addcontact":0,"age":21,"PrivateID":1460560,"ContractChanges_count_micro_noactive_all":3,"ChangeSign_sum_sum_micro_noactive_6m":np.NaN,"ChangeSign_sum_avg_all_noactive_6m":np.NaN,"ChangeSign_sum_avg_micro_noactive_all":2,"ChangeSign_sum_max_all_noactive_all":5,"ChangeType_ohe1_sum_max_all_noactive_1y":np.NaN,"ChangeType_ohe3_sum_avg_all_noactive_all":2,"ChangeType_ohe3_sum_avg_micro_noactive_1y":np.NaN,"ChangeType_ohe3_sum_min_micro_noactive_1y":np.NaN,"ChangeType_ohe3_sum_max_all_noactive_6m":np.NaN,"ChangeType_ohe3_sum_max_all_noactive_1y":np.NaN,"ChangeType_ohe3_sum_max_micro_noactive_all":5,"debt_count_all_noactive_6m":10,"DebtSignCalcLastPayout_cnt0_all_noactive_all":22,"DebtFirstSum_sum_max_all_noactive_6m":21600,"DebtFirstSum_avg_sum_all_noactive_all":161774.56,"DebtFirstSum_avg_avg_all_noactive_all":7703.550476,"DebtFirstSum_min_sum_all_noactive_1y":72874,"DebtFirstSum_min_min_all_noactive_all":2200,"DebtFirstSum_min_max_micro_noactive_all":21600,"DebtFirstSum_max_min_all_noactive_1y":3200,"DebtFirstSum_max_min_micro_noactive_all":2200,"DebtFirstSum_max_max_all_noactive_all":21600,"DebtSum_sum_avg_all_noactive_all":2377.333333,"DebtSum_avg_avg_micro_noactive_all":2377.333333,"DebtSum_min_sum_all_noactive_all":49924,"DebtSum_min_sum_micro_noactive_1y":49924,"DebtSum_min_avg_micro_noactive_6m":5547.111111,"DebtSum_min_max_all_noactive_1y":21600,"DebtSum_max_max_micro_noactive_6m":21600,"DebtSum_max_max_micro_noactive_all":21600,"DebtPercentSum_sum_avg_all_noactive_all":148.761904,"DebtPercentSum_sum_avg_micro_noactive_all":148.761904,"DebtPercentSum_avg_avg_micro_noactive_6m":347.111111,"DebtPercentSum_avg_max_micro_noactive_6m":3124,"DebtPercentSum_max_avg_all_noactive_1y":347.111111,"DebtPercentSum_max_max_micro_noactive_all":3124,"DebtOtherSum_sum_avg_micro_noactive_6m":0,"DebtOtherSum_sum_avg_micro_noactive_1y":0,"DebtOtherSum_sum_max_all_noactive_1y":0,"DebtOtherSum_avg_sum_all_noactive_all":0,"DebtOtherSum_avg_avg_all_noactive_all":0,"DebtOtherSum_avg_avg_micro_noactive_all":0,"DebtOtherSum_avg_max_all_noactive_6m":0,"DebtOtherSum_min_sum_micro_noactive_6m":0,"DebtOtherSum_min_sum_micro_noactive_all":0,"DebtOtherSum_max_avg_all_noactive_6m":0,"DebtOtherSum_max_avg_all_noactive_1y":0,"DebtCurrentDebtSum_sum_avg_micro_noactive_6m":12481,"DebtCurrentDebtSum_avg_min_micro_noactive_1y":4000,"DebtCurrentDebtSum_min_avg_all_noactive_1y":12481,"DebtCurrentDebtSum_max_max_all_noactive_all":21600,"DebtCurrentOpSum_avg_min_all_noactive_all":4000,"DebtCurrentOpSum_avg_max_all_noactive_6m":21600,"DebtCurrentOpSum_max_sum_all_noactive_1y":46800,"DebtCurrentOpSum_max_min_all_noactive_6m":4000,"DebtCurrentPercentSum_min_avg_micro_noactive_all":781,"DebtCurrentPercentSum_max_avg_all_noactive_1y":781,"DebtCurrentPercentSum_max_max_all_noactive_1y":3124,"DebtCurrentOtherSum_sum_avg_all_noactive_6m":0,"DebtCurrentOtherSum_avg_avg_all_noactive_1y":0,"DebtCurrentOtherSum_avg_avg_all_noactive_all":0,"DebtCurrentOtherSum_min_max_all_noactive_1y":0,"DebtCurrentOtherSum_min_max_all_noactive_all":0,"DebtCurrentOtherSum_max_max_all_noactive_6m":0,"DebtCurrentDebtSum_min_max_micro_noactive_all":21600,"DebtCurrentPercentSum_min_max_micro_noactive_all":3124,"A_sum_micro_noactive_all":0,"len_str_sum_micro_noactive_6m":16,"0_sum_all_noactive_all":28,"2_sum_all_noactive_all":4,"1_max_all_noactive_1y":1,"last_0_sum_micro_noactive_6m":5,"0_avg_micro_noactive_all":1,"len_str_max_micro_noactive_1y":3,"len_str_avg_all_noactive_6m":1,"last_dash_sum_all_noactive_1y":0,"C_avg_micro_noactive_all":9,"2_sum_all_noactive_6m":3,"C_max_all_noactive_6m":2,"last_C_sum_all_noactive_all":14,"S_max_all_noactive_all":0,"len_str_sum_all_noactive_all":50,"C_avg_micro_noactive_6m":0,"dash_max_all_noactive_1y":0,"A_max_all_noactive_all":0,"len_str_max_all_noactive_all":7,"0_avg_all_noactive_1y":1,"dash_max_micro_noactive_all":0,"len_str_avg_micro_noactive_all":2,"0_max_all_noactive_all":4,"1_max_all_noactive_all":1,"len_str_avg_all_noactive_1y":1,"C_max_all_noactive_all":20,"len_str_max_micro_noactive_all":7,"0_max_all_noactive_1y":2,"dash_max_micro_noactive_6m":0,"2_max_micro_noactive_all":1,"len_str_max_all_noactive_6m":3,"2_max_all_noactive_all":1,"1_max_micro_noactive_all":1,"0_avg_all_noactive_all":1,"C_max_micro_noactive_1y":2,"0_max_micro_noactive_1y":2,"dash_sum_micro_noactive_all":0,"0_max_all_noactive_6m":2,"3_max_all_noactive_all":1,"len_str_max_micro_noactive_6m":3,"0_max_micro_noactive_all":4,"n1000_count_n1000_0_micro_noactive_1y":5,"n1000_count_n1000_0_micro_noactive_all":17,"n1000_count_n1000_1_all_noactive_all":0,"n1000_count_n1000_2_all_noactive_all":0,"n1001_min_all_noactive_all":np.NaN,"n1001_max_all_noactive_1y":np.NaN,"n1002_max_all_noactive_6m":21600,"n1002_min_all_noactive_1y":4000,"n1002_max_all_noactive_1y":21600,"n1002_sum_all_noactive_all":65300,"n1002_avg_all_noactive_all":13060,"n1002_sum_micro_noactive_1y":65300,"n1002_max_micro_noactive_1y":21600,"n1002_avg_micro_noactive_all":13060,"n1003_avg_all_noactive_all":0,"n1003_sum_micro_noactive_6m":0,"n1004_sum_all_noactive_6m":6,"n1004_avg_all_noactive_1y":1.2,"n1004_max_all_noactive_1y":2,"n1004_max_all_noactive_all":2,"n1004_avg_micro_noactive_6m":1.2,"n1004_avg_micro_noactive_all":1.2,"n1005_min_all_noactive_6m":292,"n1005_avg_all_noactive_1y":292,"n1005_min_all_noactive_all":292,"n1005_avg_micro_noactive_all":292,"n1005_avg_micro_noactive_6m":292,"n1005_min_micro_noactive_all":292,"n1006_max_all_noactive_1y":23001.67,"n1006_min_all_noactive_all":4973.33,"n1006_min_micro_noactive_6m":4973.33,"n1006_avg_micro_noactive_6m":13691.8,"n1006_max_micro_noactive_1y":23001.67,"n1006_max_micro_noactive_all":23001.67,"n1007_avg_all_noactive_all":17,"n1007_max_all_noactive_all":17,"Delay5_sum_all_noactive_all":0,"Delay30_sum_all_noactive_1y":3,"Delay30_max_all_noactive_all":1,"Delay60_sum_all_noactive_all":0,"Delay90_sum_all_noactive_all":0,"DelayMore_sum_all_noactive_all":1,"CredMaxOverdue_sum_all_noactive_6m":18374,"CredMaxOverdue_avg_all_noactive_6m":1837.4,"CredMaxOverdue_max_all_noactive_6m":9000,"CredMaxOverdue_avg_all_noactive_1y":1837.4,"CredMaxOverdue_max_all_noactive_1y":9000,"CredMaxOverdue_avg_all_noactive_all":1480.661818,"CredMaxOverdue_max_all_noactive_all":14200.56,"JointDebtors_count_all_noactive_all":14,"JointDebtors_count_micro_noactive_1y":6,"ContractEndDateDaysFromDeal_sum_micro_noactive_all":781,"ContractAmountSum_sum_all_noactive_1y":91374,"ContractAmountSum_sum_all_noactive_all":180274.56,"ContractAmountSum_avg_all_noactive_1y":9137.4,"ContractAmountSum_avg_all_noactive_all":8194.298181,"ContractAmountSum_avg_micro_noactive_all":8194.298181,"ContractAmountSum_min_all_noactive_6m":3200,"ContractAmountSum_min_all_noactive_all":2200,"ContractAmountSum_max_all_noactive_6m":21600,"ContractAmountSum_max_all_noactive_all":21600,"ContractAmountSum_max_micro_noactive_6m":21600,"ContractAmountCurrencyIsRUR_sum_all_noactive_all":22,"ContractAmountSum_max_micro_noactive_all":21600,"CourtSign_oheNULL_sum_micro_noactive_all":22,"CourtDisputeCase_oheNULL_sum_micro_noactive_1y":10,"Deal_count_all_noactive_all":22,"DealType_ohe1_sum_all_noactive_1y":0,"DealType_ohe5_sum_all_noactive_all":0,"DealPurposeID_ohe99_sum_micro_noactive_1y":6,"DealPurposeID_ohe15_sum_all_noactive_all":0,"DealDays_sum_all_noactive_1y":255,"DealDays_sum_all_noactive_all":833,"DealDays_avg_all_noactive_6m":25,"DealDays_avg_all_noactive_all":37,"DealDays_avg_micro_noactive_6m":25,"DealDays_min_all_noactive_all":3,"DealDays_max_all_noactive_6m":33,"DealDays_max_micro_noactive_6m":33,"DealDays_max_micro_noactive_all":125,"DealCredOwnerTypeIsNull_sum_micro_noactive_1y":4,"FullCostPercent_avg_all_noactive_6m":284.7,"FullCostPercent_avg_micro_noactive_all":324.320454,"FullCostPercent_min_all_noactive_1y":219,"FullCostPercent_min_all_noactive_all":219,"FullCostPercent_min_micro_noactive_1y":219,"FullCostPercent_min_micro_noactive_all":219,"FullCostSum_sum_all_noactive_1y":51575.64,"FullCostSum_sum_micro_noactive_1y":51575.64,"FullCostSum_avg_all_noactive_1y":5157.564,"FullCostSum_avg_all_noactive_all":4191.24647,"FullCostSum_avg_micro_noactive_1y":5157.564,"FullCostSum_min_all_noactive_1y":76.8,"FullCostSum_max_all_noactive_6m":22940,"FullCostSum_max_all_noactive_all":22940,"FullCostSum_max_micro_noactive_1y":22940,"CredStartDebtDaysFromDeal_sum_all_noactive_all":0,"CredStartDebtDaysFromDeal_max_all_noactive_1y":0,"CredStartDebtDaysFromDeal_max_all_noactive_all":0,"AveragePaymentSum_sum_all_noactive_6m":38897,"AveragePaymentSum_sum_all_noactive_all":38897,"AveragePaymentSum_avg_all_noactive_6m":4321.888888,"AveragePaymentSum_avg_all_noactive_1y":4321.888888,"AveragePaymentSum_avg_all_noactive_all":2431.0625,"AveragePaymentSum_avg_micro_noactive_all":2431.0625,"AveragePaymentSum_max_all_noactive_6m":17124,"AveragePaymentSum_max_all_noactive_1y":17124,"AveragePaymentSum_max_micro_noactive_all":17124,"ContractEndReason_ohe1_sum_all_noactive_all":15,"ContractEndReason_ohe1_sum_micro_noactive_6m":5,"ContractEndReason_oheNULL_sum_all_noactive_all":5,"ContractEndDateDaysFromDeal_sum_all_noactive_all":781,"ContractEndDateDaysFromDeal_avg_all_noactive_all":45,"ContractEndDateDaysFromDeal_avg_micro_noactive_all":45,"ContractEndDateDaysFromDeal_min_all_noactive_all":3,"ContractEndDateDaysFromDeal_max_all_noactive_6m":40,"ContractEndDateDaysFromDeal_max_all_noactive_1y":40,"ContractEndDateDaysFromDeal_max_all_noactive_all":149,"ContractEndDateDaysFromDeal_max_micro_noactive_all":149,"Payments_count_all_noactive_all":22,"LastPayoutSum_sum_max_all_noactive_6m":11664,"LastPayoutSum_avg_avg_all_noactive_1y":3525.606666,"LastPayoutSum_avg_avg_micro_noactive_all":6866.414761,"LastPayoutSum_min_max_all_noactive_1y":11664,"LastPayoutSum_min_max_all_noactive_all":28871.32,"LastPayoutSum_max_max_micro_noactive_1y":11664,"LastPayoutOpSum_min_sum_all_noactive_all":113265.12,"LastPayoutOpSum_min_min_micro_noactive_6m":3200,"LastPayoutOpSum_max_avg_all_noactive_all":6662.654117,"LastPayoutOpSum_max_min_all_noactive_1y":3200,"LastPayoutPercentSum_sum_max_micro_noactive_6m":2664,"LastPayoutPercentSum_avg_min_micro_noactive_1y":76.8,"LastPayoutPercentSum_min_avg_micro_noactive_1y":1127.862,"LastPayoutPercentSum_min_max_all_noactive_1y":2664,"LastPayoutOtherSum_avg_max_all_noactive_1y":17.15,"LastPayoutOtherSum_min_sum_all_noactive_all":748.48,"LastPayoutOtherSum_min_avg_all_noactive_all":74.848,"LastPayoutOtherSum_min_avg_micro_noactive_1y":4.2875,"LastPayoutOtherSum_min_avg_micro_noactive_all":74.848,"LastPayoutOtherSum_min_max_all_noactive_6m":17.15,"LastPayoutOtherSum_max_sum_micro_noactive_6m":17.15,"LastPayoutOtherSum_max_avg_all_noactive_6m":4.2875,"LastPayoutOtherSum_max_avg_all_noactive_1y":4.2875,"PaidSum_sum_avg_all_noactive_all":9418.645263,"PaidSum_min_avg_all_noactive_1y":4604.351428,"PaidSum_min_avg_micro_noactive_all":9418.645263,"PaidSum_max_sum_all_noactive_1y":32230.46,"PaidOpSum_sum_max_all_noactive_6m":9000,"PaidOpSum_sum_max_micro_noactive_6m":9000,"PaidOpSum_min_avg_micro_noactive_1y":3724.857142,"PaidOpSum_max_avg_all_noactive_6m":3724.857142,"PaidOpSum_max_max_all_noactive_1y":9000,"PaidOpSum_max_max_all_noactive_all":16300,"PaidOpSum_min_max_micro_noactive_all":16300,"PaidPercentSum_sum_avg_all_noactive_1y":877.045714,"PaidPercentSum_sum_avg_micro_noactive_6m":877.045714,"PaidPercentSum_avg_avg_all_noactive_all":3769.660714,"PaidPercentSum_min_avg_micro_noactive_all":3769.660714,"PaidPercentSum_min_max_all_noactive_1y":2664,"PaidPercentSum_max_sum_micro_noactive_6m":6139.32,"PaidPercentSum_max_max_all_noactive_6m":2664,"PaidPercentSum_max_max_all_noactive_all":20569.53,"PaidOtherSum_sum_sum_all_noactive_1y":17.14,"PaidOtherSum_sum_sum_micro_noactive_all":748.46,"PaidOtherSum_avg_sum_micro_noactive_6m":17.14,"PaidOtherSum_avg_avg_all_noactive_1y":2.448571,"PaidOtherSum_min_max_all_noactive_6m":17.14,"PaidOtherSum_max_avg_all_noactive_6m":2.448571,"PaidOtherSum_max_avg_all_noactive_all":53.461428,"PaidOtherSum_max_avg_micro_noactive_1y":2.448571,"PaidOtherSum_max_avg_micro_noactive_all":53.461428,"PaidOtherSum_max_max_all_noactive_all":731.32,"OverdueDay_sum_sum_micro_noactive_6m":0,"OverdueDay_sum_avg_all_noactive_all":0,"OverdueDay_sum_avg_micro_noactive_all":0,"OverdueDay_avg_max_all_noactive_1y":0,"OverdueDay_min_max_all_noactive_all":0,"OverdueDay_min_max_micro_noactive_all":0,"SizePaymentsTypeID_ohe1_avg_sum_micro_noactive_1y":5,"SizePaymentsTypeID_ohe2_avg_sum_all_noactive_all":1,"SizePaymentsTypeID_ohe3_avg_sum_micro_noactive_1y":4,"DeadlineTypeID_ohe3_sum_sum_micro_noactive_6m":0,"PaymentTerms_count_all_noactive_6m":10,"Regularity_ohe99_sum_sum_all_noactive_1y":1,"NextPayoutSum_sum_sum_all_noactive_all":46800,"Regularity_ohe1_sum_sum_micro_noactive_all":0,"Regularity_ohe3_avg_max_all_noactive_6m":0,"NextPayoutSum_avg_max_all_noactive_1y":21600,"NextPayoutSum_max_avg_micro_noactive_6m":4680,"PercentNextPayoutSum_min_avg_all_noactive_6m":1790,"NextPayoutSum_sum_max_micro_noactive_6m":21600,"PercentNextPayoutSum_avg_max_micro_noactive_1y":5702.4,"NextPayoutSum_max_avg_all_noactive_1y":4680,"Regularity_ohe3_avg_sum_all_noactive_6m":0,"PercentNextPayoutSum_avg_sum_all_noactive_all":11370,"NextPayoutSum_avg_avg_all_noactive_all":2752.941176,"Regularity_ohe2_sum_sum_micro_noactive_6m":0,"Regularity_ohe2_sum_max_micro_noactive_all":0,"Regularity_ohe3_sum_sum_all_noactive_all":0,"Regularity_ohe3_avg_sum_micro_noactive_1y":0,"NextPayoutSum_sum_max_all_noactive_all":21600,"PercentNextPayoutSum_sum_max_all_noactive_all":5702.4,"PercentNextPayoutSum_min_avg_all_noactive_all":1624.285714,"NextPayoutSum_min_max_all_noactive_6m":21600}
df = pd.json_normalize(data)

# %%
df
# Out:
#    ScoringAmount  Score  ActivityType Education  Gender  LoanPurpose  \
# 0           5900    500           NaN   Среднее       1          NaN
#
#    MaritalStatus  MonthlyIncome     Post   OrganizationPhone  ...  \
# 0              0          45000  Рабочий  +7 (391) 274-94-11  ...
#
#    PercentNextPayoutSum_avg_sum_all_noactive_all  \
# 0                                          11370
#
#    NextPayoutSum_avg_avg_all_noactive_all  \
# 0                             2752.941176
#
#    Regularity_ohe2_sum_sum_micro_noactive_6m  \
# 0                                          0
#
#    Regularity_ohe2_sum_max_micro_noactive_all  \
# 0                                           0
#
#   Regularity_ohe3_sum_sum_all_noactive_all  \
# 0                                        0
#
#    Regularity_ohe3_avg_sum_micro_noactive_1y  \
# 0                                          0
#
#    NextPayoutSum_sum_max_all_noactive_all  \
# 0                                   21600
#
# ...

# %%
#df = pd.read_csv('test_for_test_obrabotki.csv', sep=';', index_col=0)

# %% [markdown]
# ## приводим к необходимым типам данных

# %%
result = {'object': ['DraftId', 'ActivityType', 'Education', 'LoanPurpose', 'Post', 'OrganizationPhone', 'StoreName', 'Bank'], 'float64': ['Score', 'ScoringAmount', 'A_sum_micro_noactive_all', 'len_str_sum_micro_noactive_6m', '0_sum_all_noactive_all', '2_sum_all_noactive_all', '1_max_all_noactive_1y', 'last_0_sum_micro_noactive_6m', '0_avg_micro_noactive_all', 'len_str_max_micro_noactive_1y', 'len_str_avg_all_noactive_6m', 'last_dash_sum_all_noactive_1y', 'C_avg_micro_noactive_all', '2_sum_all_noactive_6m', 'C_max_all_noactive_6m', 'last_C_sum_all_noactive_all', 'S_max_all_noactive_all', 'len_str_sum_all_noactive_all', 'C_avg_micro_noactive_6m', 'dash_max_all_noactive_1y', 'A_max_all_noactive_all', 'len_str_max_all_noactive_all', '0_avg_all_noactive_1y', 'dash_max_micro_noactive_all', 'len_str_avg_micro_noactive_all', '0_max_all_noactive_all', '1_max_all_noactive_all', 'len_str_avg_all_noactive_1y', 'C_max_all_noactive_all', 'len_str_max_micro_noactive_all', '0_max_all_noactive_1y', 'dash_max_micro_noactive_6m', '2_max_micro_noactive_all', 'len_str_max_all_noactive_6m', '2_max_all_noactive_all', '1_max_micro_noactive_all', '0_avg_all_noactive_all', 'C_max_micro_noactive_1y', '0_max_micro_noactive_1y', 'dash_sum_micro_noactive_all', '0_max_all_noactive_6m', '3_max_all_noactive_all', 'len_str_max_micro_noactive_6m', '0_max_micro_noactive_all', 'PaymentTerms_count_all_noactive_6m', 'Regularity_ohe99_sum_sum_all_noactive_1y', 'NextPayoutSum_sum_sum_all_noactive_all', 'Regularity_ohe1_sum_sum_micro_noactive_all', 'Regularity_ohe3_avg_max_all_noactive_6m', 'NextPayoutSum_avg_max_all_noactive_1y', 'NextPayoutSum_max_avg_micro_noactive_6m', 'PercentNextPayoutSum_min_avg_all_noactive_6m', 'NextPayoutSum_sum_max_micro_noactive_6m', 'PercentNextPayoutSum_avg_max_micro_noactive_1y', 'NextPayoutSum_max_avg_all_noactive_1y', 'Regularity_ohe3_avg_sum_all_noactive_6m', 'PercentNextPayoutSum_avg_sum_all_noactive_all', 'NextPayoutSum_avg_avg_all_noactive_all', 'Regularity_ohe2_sum_sum_micro_noactive_6m', 'Regularity_ohe2_sum_max_micro_noactive_all', 'Regularity_ohe3_sum_sum_all_noactive_all', 'Regularity_ohe3_avg_sum_micro_noactive_1y', 'NextPayoutSum_sum_max_all_noactive_all', 'PercentNextPayoutSum_sum_max_all_noactive_all', 'PercentNextPayoutSum_min_avg_all_noactive_all', 'NextPayoutSum_min_max_all_noactive_6m', 'ContractAmountCurrencyIsRUR_sum_all_noactive_all', 'ContractAmountSum_avg_all_noactive_1y', 'ContractAmountSum_avg_all_noactive_all', 'ContractAmountSum_min_all_noactive_all', 'ContractAmountSum_max_all_noactive_all', 'ContractAmountSum_max_micro_noactive_6m', 'ContractAmountSum_max_all_noactive_6m', 'ContractAmountSum_sum_all_noactive_1y', 'ContractAmountSum_avg_micro_noactive_all', 'ContractAmountSum_max_micro_noactive_all', 'ContractAmountSum_min_all_noactive_6m', 'ContractAmountSum_sum_all_noactive_all', 'Delay90_sum_all_noactive_all', 'CredMaxOverdue_max_all_noactive_all', 'Delay30_max_all_noactive_all', 'CredMaxOverdue_max_all_noactive_6m', 'CredMaxOverdue_avg_all_noactive_all', 'Delay30_sum_all_noactive_1y', 'CredMaxOverdue_sum_all_noactive_6m', 'DelayMore_sum_all_noactive_all', 'CredMaxOverdue_max_all_noactive_1y', 'CredMaxOverdue_avg_all_noactive_6m', 'Delay5_sum_all_noactive_all', 'Delay60_sum_all_noactive_all', 'CredMaxOverdue_avg_all_noactive_1y', 'ChangeType_ohe3_sum_max_all_noactive_6m', 'ChangeSign_sum_sum_micro_noactive_6m', 'ChangeType_ohe1_sum_max_all_noactive_1y', 'ChangeSign_sum_max_all_noactive_all', 'ContractChanges_count_micro_noactive_all', 'ChangeType_ohe3_sum_min_micro_noactive_1y', 'ChangeSign_sum_avg_all_noactive_6m', 'ChangeType_ohe3_sum_avg_micro_noactive_1y', 'ChangeType_ohe3_sum_avg_all_noactive_all', 'ChangeType_ohe3_sum_max_all_noactive_1y', 'ChangeSign_sum_avg_micro_noactive_all', 'ChangeType_ohe3_sum_max_micro_noactive_all', 'CourtDisputeCase_oheNULL_sum_micro_noactive_1y', 'CourtSign_oheNULL_sum_micro_noactive_all', 'DealCredOwnerTypeIsNull_sum_micro_noactive_1y', 'DealPurposeID_ohe99_sum_micro_noactive_1y', 'DealDays_avg_micro_noactive_6m', 'DealDays_min_all_noactive_all', 'Deal_count_all_noactive_all', 'DealDays_sum_all_noactive_1y', 'DealDays_max_micro_noactive_all', 'DealPurposeID_ohe15_sum_all_noactive_all', 'DealDays_sum_all_noactive_all', 'DealDays_max_all_noactive_6m', 'DealDays_max_micro_noactive_6m', 'DealDays_avg_all_noactive_6m', 'DealDays_avg_all_noactive_all', 'DealType_ohe1_sum_all_noactive_1y', 'DealType_ohe5_sum_all_noactive_all', 'DebtCurrentOpSum_max_min_all_noactive_6m', 'DebtCurrentPercentSum_max_avg_all_noactive_1y', 'DebtCurrentOtherSum_avg_avg_all_noactive_1y', 'DebtCurrentDebtSum_sum_avg_micro_noactive_6m', 'DebtCurrentDebtSum_avg_min_micro_noactive_1y', 'DebtCurrentDebtSum_min_max_micro_noactive_all', 'DebtCurrentPercentSum_min_avg_micro_noactive_all', 'DebtCurrentOtherSum_min_max_all_noactive_all', 'DebtCurrentPercentSum_min_max_micro_noactive_all', 'DebtCurrentOpSum_avg_min_all_noactive_all', 'DebtCurrentOpSum_max_sum_all_noactive_1y', 'DebtCurrentOpSum_avg_max_all_noactive_6m', 'DebtCurrentPercentSum_max_max_all_noactive_1y', 'DebtCurrentOtherSum_max_max_all_noactive_6m', 'DebtCurrentDebtSum_max_max_all_noactive_all', 'DebtCurrentDebtSum_min_avg_all_noactive_1y', 'DebtCurrentOtherSum_sum_avg_all_noactive_6m', 'DebtCurrentOtherSum_min_max_all_noactive_1y', 'DebtCurrentOtherSum_avg_avg_all_noactive_all', 'ContractEndDateDaysFromDeal_min_all_noactive_all', 'ContractEndDateDaysFromDeal_avg_micro_noactive_all', 'ContractEndReason_ohe1_sum_micro_noactive_6m', 'FullCostSum_max_all_noactive_6m', 'FullCostSum_avg_all_noactive_1y', 'AveragePaymentSum_sum_all_noactive_6m', 'FullCostSum_sum_micro_noactive_1y', 'AveragePaymentSum_avg_all_noactive_6m', 'FullCostPercent_min_micro_noactive_1y', 'ContractEndDateDaysFromDeal_max_all_noactive_all', 'FullCostPercent_avg_all_noactive_6m', 'ContractEndReason_ohe1_sum_all_noactive_all', 'FullCostSum_min_all_noactive_1y', 'ContractEndReason_oheNULL_sum_all_noactive_all', 'AveragePaymentSum_max_all_noactive_1y', 'AveragePaymentSum_max_all_noactive_6m', 'FullCostSum_avg_micro_noactive_1y', 'FullCostSum_sum_all_noactive_1y', 'FullCostSum_max_all_noactive_all', 'ContractEndDateDaysFromDeal_sum_all_noactive_all', 'FullCostPercent_min_all_noactive_all', 'ContractEndDateDaysFromDeal_max_all_noactive_1y', 'FullCostSum_max_micro_noactive_1y', 'CredStartDebtDaysFromDeal_sum_all_noactive_all', 'AveragePaymentSum_max_micro_noactive_all', 'FullCostPercent_min_micro_noactive_all', 'FullCostSum_avg_all_noactive_all', 'CredStartDebtDaysFromDeal_max_all_noactive_1y', 'ContractEndDateDaysFromDeal_max_micro_noactive_all', 'AveragePaymentSum_avg_all_noactive_all', 'ContractEndDateDaysFromDeal_max_all_noactive_6m', 'AveragePaymentSum_avg_micro_noactive_all', 'AveragePaymentSum_sum_all_noactive_all', 'ContractEndDateDaysFromDeal_avg_all_noactive_all', 'CredStartDebtDaysFromDeal_max_all_noactive_all', 'FullCostPercent_avg_micro_noactive_all', 'FullCostPercent_min_all_noactive_1y', 'AveragePaymentSum_avg_all_noactive_1y', 'ContractEndDateDaysFromDeal_sum_micro_noactive_all', 'JointDebtors_count_micro_noactive_1y', 'JointDebtors_count_all_noactive_all', 'n1007_avg_all_noactive_all', 'n1002_max_micro_noactive_1y', 'n1005_avg_micro_noactive_6m', 'n1004_sum_all_noactive_6m', 'n1002_sum_micro_noactive_1y', 'n1005_min_all_noactive_6m', 'n1006_max_micro_noactive_1y', 'n1006_avg_micro_noactive_6m', 'n1007_max_all_noactive_all', 'n1001_min_all_noactive_all', 'n1002_avg_all_noactive_all', 'n1001_max_all_noactive_1y', 'n1006_max_micro_noactive_all', 'n1006_max_all_noactive_1y', 'n1002_min_all_noactive_1y', 'n1002_sum_all_noactive_all', 'n1005_min_micro_noactive_all', 'n1000_count_n1000_2_all_noactive_all', 'n1004_avg_all_noactive_1y', 'n1006_min_micro_noactive_6m', 'n1003_sum_micro_noactive_6m', 'n1004_max_all_noactive_1y', 'n1004_avg_micro_noactive_all', 'n1003_avg_all_noactive_all', 'n1002_max_all_noactive_1y', 'n1002_max_all_noactive_6m', 'n1002_avg_micro_noactive_all', 'n1000_count_n1000_0_micro_noactive_1y', 'n1004_max_all_noactive_all', 'n1000_count_n1000_0_micro_noactive_all', 'n1005_avg_all_noactive_1y', 'n1000_count_n1000_1_all_noactive_all', 'n1004_avg_micro_noactive_6m', 'n1005_avg_micro_noactive_all', 'n1006_min_all_noactive_all', 'n1005_min_all_noactive_all', 'DebtSignCalcLastPayout_cnt0_all_noactive_all', 'DebtFirstSum_max_min_all_noactive_1y', 'DebtFirstSum_max_min_micro_noactive_all', 'DebtSum_min_max_all_noactive_1y', 'DebtFirstSum_sum_max_all_noactive_6m', 'DebtSum_max_max_micro_noactive_6m', 'DebtSum_min_sum_micro_noactive_1y', 'DebtSum_min_avg_micro_noactive_6m', 'DebtPercentSum_sum_avg_all_noactive_all', 'DebtFirstSum_min_sum_all_noactive_1y', 'DebtOtherSum_min_sum_micro_noactive_6m', 'DebtSum_min_sum_all_noactive_all', 'DebtOtherSum_sum_max_all_noactive_1y', 'DebtOtherSum_avg_sum_all_noactive_all', 'DebtPercentSum_avg_max_micro_noactive_6m', 'DebtOtherSum_max_avg_all_noactive_1y', 'DebtOtherSum_max_avg_all_noactive_6m', 'DebtSum_sum_avg_all_noactive_all', 'DebtOtherSum_avg_max_all_noactive_6m', 'DebtPercentSum_sum_avg_micro_noactive_all', 'DebtFirstSum_min_min_all_noactive_all', 'debt_count_all_noactive_6m', 'DebtFirstSum_avg_sum_all_noactive_all', 'DebtPercentSum_max_avg_all_noactive_1y', 'DebtFirstSum_max_max_all_noactive_all', 'DebtPercentSum_avg_avg_micro_noactive_6m', 'DebtOtherSum_avg_avg_all_noactive_all', 'DebtFirstSum_min_max_micro_noactive_all', 'DebtPercentSum_max_max_micro_noactive_all', 'DebtSum_max_max_micro_noactive_all', 'DebtOtherSum_min_sum_micro_noactive_all', 'DebtSum_avg_avg_micro_noactive_all', 'DebtOtherSum_sum_avg_micro_noactive_6m', 'DebtOtherSum_avg_avg_micro_noactive_all', 'DebtFirstSum_avg_avg_all_noactive_all', 'DebtOtherSum_sum_avg_micro_noactive_1y', 'PaidOpSum_sum_max_micro_noactive_6m', 'PaidPercentSum_max_max_all_noactive_all', 'LastPayoutOtherSum_max_sum_micro_noactive_6m', 'PaidSum_max_sum_all_noactive_1y', 'PaidOtherSum_max_avg_micro_noactive_1y', 'PaidPercentSum_max_sum_micro_noactive_6m', 'LastPayoutOtherSum_max_avg_all_noactive_6m', 'LastPayoutOtherSum_min_avg_micro_noactive_all', 'LastPayoutOtherSum_max_avg_all_noactive_1y', 'PaidSum_min_avg_micro_noactive_all', 'PaidOpSum_min_max_micro_noactive_all', 'LastPayoutOtherSum_min_avg_all_noactive_all', 'LastPayoutPercentSum_avg_min_micro_noactive_1y', 'LastPayoutPercentSum_min_avg_micro_noactive_1y', 'Payments_count_all_noactive_all', 'PaidOtherSum_avg_sum_micro_noactive_6m', 'PaidOtherSum_max_max_all_noactive_all', 'OverdueDay_avg_max_all_noactive_1y', 'LastPayoutOpSum_max_avg_all_noactive_all', 'PaidSum_sum_avg_all_noactive_all', 'PaidPercentSum_max_max_all_noactive_6m', 'PaidOtherSum_avg_avg_all_noactive_1y', 'LastPayoutSum_avg_avg_micro_noactive_all', 'PaidOtherSum_sum_sum_micro_noactive_all', 'SizePaymentsTypeID_ohe1_avg_sum_micro_noactive_1y', 'SizePaymentsTypeID_ohe3_avg_sum_micro_noactive_1y', 'PaidOpSum_min_avg_micro_noactive_1y', 'DeadlineTypeID_ohe3_sum_sum_micro_noactive_6m', 'LastPayoutOpSum_min_sum_all_noactive_all', 'LastPayoutPercentSum_sum_max_micro_noactive_6m', 'PaidOtherSum_sum_sum_all_noactive_1y', 'LastPayoutOtherSum_avg_max_all_noactive_1y', 'LastPayoutSum_sum_max_all_noactive_6m', 'OverdueDay_min_max_all_noactive_all', 'PaidOpSum_max_max_all_noactive_1y', 'LastPayoutOtherSum_min_avg_micro_noactive_1y', 'LastPayoutPercentSum_min_max_all_noactive_1y', 'LastPayoutSum_max_max_micro_noactive_1y', 'LastPayoutOpSum_max_min_all_noactive_1y', 'PaidOtherSum_max_avg_all_noactive_all', 'LastPayoutSum_avg_avg_all_noactive_1y', 'LastPayoutOtherSum_min_max_all_noactive_6m', 'PaidOpSum_sum_max_all_noactive_6m', 'LastPayoutOpSum_min_min_micro_noactive_6m', 'OverdueDay_sum_sum_micro_noactive_6m', 'OverdueDay_sum_avg_all_noactive_all', 'LastPayoutSum_min_max_all_noactive_all', 'PaidPercentSum_sum_avg_all_noactive_1y', 'PaidOtherSum_min_max_all_noactive_6m', 'PaidPercentSum_min_max_all_noactive_1y', 'PaidPercentSum_sum_avg_micro_noactive_6m', 'PaidOpSum_max_avg_all_noactive_6m', 'LastPayoutOtherSum_min_sum_all_noactive_all', 'PaidOpSum_max_max_all_noactive_all', 'LastPayoutSum_min_max_all_noactive_1y', 'SizePaymentsTypeID_ohe2_avg_sum_all_noactive_all', 'OverdueDay_min_max_micro_noactive_all', 'PaidSum_min_avg_all_noactive_1y', 'PaidPercentSum_min_avg_micro_noactive_all', 'PaidOtherSum_max_avg_all_noactive_6m', 'OverdueDay_sum_avg_micro_noactive_all', 'PaidOtherSum_max_avg_micro_noactive_all', 'PaidPercentSum_avg_avg_all_noactive_all', 'MaritalStatus', 'MonthlyIncome', 'Bin'], 'int64': ['Gender', 'InsurancePolicy', 'VerifiedByESIA', 'EMailVerified', 'RegisterSameFact', 'mobile', 'PingTreeLead', 'mask_person_addcontact', 'age']}

# %%
for dtype, columns in result.items():
    for column in columns:
        if column in df.columns:
            df[column] = df[column].astype(dtype)
        else:
            print(f"Столбец '{column}' не найден")
# Out:
# Столбец 'DraftId' не найден

# %% [markdown]
# <a id='обработка-данных'></a>
# ## Обработка данных

# %%
df['OrganizationPhone'] = df['OrganizationPhone'].astype('str')
df['OrganizationPhone_group'] = df.apply(lambda x: 1 if '+7 (9' in x['OrganizationPhone'] else 2, axis = 1)
df['OrganizationPhone_group'] = df.apply(lambda x: 3 if '+7 (4' in x['OrganizationPhone']
                                                 else x['OrganizationPhone_group'], axis = 1)
df['OrganizationPhone_group'] = df.apply(lambda x: 4 if 'nan' in x['OrganizationPhone']
                                                 else x['OrganizationPhone_group'], axis = 1)
del df['OrganizationPhone']

df = df.applymap(lambda x: x.upper() if isinstance(x, str) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'SBER' if 'SBER' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'TINKOFF' if 'TINKOFF' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'ALFA-BANK' if 'ALFA-BANK' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'VTB' if 'VTB' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'RAIFFEISENBANK' if 'RAIFFEISENBANK' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'OTKRITIE' if 'OTKRITIE' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'QIWI' if 'QIWI' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'POCHTA BANK' if 'POCHTA' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'GAZPROMBANK' if 'GAZPROMBANK' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'PROMSVYAZBANK' if 'PROMSVYAZBANK' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'AGRICULTURAL BANK' if 'AGRICULTURAL BANK' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'AK BARS' if 'AK BARS' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'HOME' if 'HOME CREDIT' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'URALSIB' if 'URALSIB' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'ROSBANK' if 'ROSBANK' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'YANDEX' if 'YANDEX' in str(x) else x)
df['Bank'] = df['Bank'].apply(lambda x: 'UNICREDIT' if 'UNICREDIT' in str(x) else x)

df['Gender'] = df['Gender'] - 1

attribs=[ 'InsurancePolicy', 'VerifiedByESIA', 'EMailVerified', 
          'RegisterSameFact',  'StoreName', 'mobile', 
          'PingTreeLead', 'Bin', 'Bank', 
          'mask_person_addcontact', 'ActivityType', 'Education', 
          'Gender', 'LoanPurpose', 'MaritalStatus',
          'MonthlyIncome', 'Post', 'OrganizationPhone_group']
df[attribs] = df[attribs].fillna('0')

df[['Gender', 'OrganizationPhone_group', 
    'RegisterSameFact',  'Bin']]=df[['Gender', 'OrganizationPhone_group', 
                                                 'RegisterSameFact',  'Bin']].astype(float)
df[attribs] = df[attribs].astype(str)

# %%
df
# Out:
#    ScoringAmount  Score ActivityType Education Gender LoanPurpose  \
# 0         5900.0  500.0            0   СРЕДНЕЕ    0.0           0
#
#   MaritalStatus MonthlyIncome     Post InsurancePolicy  ...  \
# 0           0.0       45000.0  РАБОЧИЙ               1  ...
#
#   NextPayoutSum_avg_avg_all_noactive_all  \
# 0                            2752.941176
#
#   Regularity_ohe2_sum_sum_micro_noactive_6m  \
# 0                                       0.0
#
#   Regularity_ohe2_sum_max_micro_noactive_all  \
# 0                                        0.0
#
#   Regularity_ohe3_sum_sum_all_noactive_all  \
# 0                                      0.0
#
#   Regularity_ohe3_avg_sum_micro_noactive_1y  \
# 0                                       0.0
#
#   NextPayoutSum_sum_max_all_noactive_all  \
# 0                                21600.0
#
#   PercentNextPayoutSum_sum_max_all_noactive_all  \
# 0                                        5702.4
#
#   PercentNextPayoutSum_min_avg_all_noactive_all  \
# ...

# %% [markdown]
# <a id='убираем-хвосты'></a>
# ## Убираем хвосты

# %%
columns_dict = {'InsurancePolicy': ['1', '0'], 
                'VerifiedByESIA': ['0', '1'], 
                'EMailVerified': ['0', '1'], 
                'RegisterSameFact': ['1.0', '0.0'],
                'StoreName': ['WEBSITE', 'PLAYMARKET', 'APPSTORE', 'APPGALLERY'], 
                'mobile': ['0', '1'], 
                'PingTreeLead': ['0', '1'], 
                'Bin': ['220220.0', '220070.0', '553691.0', '220024.0', '220015.0', '522860.0', '427938.0', '437772.0', '481776.0', '220028.0', '220029.0', '533669.0', '220073.0', '427616.0', '546998.0', '555949.0', '220432.0', '220077.0', '220030.0', '220027.0', '427638.0', '536829.0', '220002.0', '427432.0', '489347.0', '427640.0', '458443.0', '489049.0', '546940.0', '424917.0', '427630.0', '220003.0', '546938.0', '427655.0', '469395.0', '427667.0', '220001.0', '537965.0', '220038.0', '220431.0', '220424.0', '220412.0', '676907.0', '427660.0', '220053.0', '220341.0', '521324.0', '220039.0', '446915.0', '400680.0', '220019.0', '558620.0', '427606.0', '553609.0', '427662.0', '427652.0', '546955.0', '524602.0', '427631.0', '546960.0', '405870.0', '546930.0', '528041.0', '427650.0', '447624.0', '524614.0', '220026.0', '427654.0', '427672.0', '427642.0', '427626.0', '220045.0', '427602.0', '546967.0', '427618.0', '437773.0', '639002.0', '427649.0', '538150.0', '427644.0', '220196.0', '220048.0', '546962.0', '427613.0', '546952.0', '676454.0', '546906.0', '427611.0', '552175.0', '427646.0', '427656.0', '546916.0', '427676.0', '536672.0', '220050.0', '559900.0', '477986.0', '220156.0', '220011.0', '435303.0', '427670.0', '546931.0', '539877.0', '404802.0', '427666.0', '489042.0', '510069.0', '546956.0', '427645.0', '510621.0', '546918.0', '220008.0', '546972.0', '427663.0', '516473.0', '527269.0', '546942.0', '427610.0', '220033.0', '546944.0', '427603.0', '546954.0', '427622.0', '546949.0', '427664.0', '427675.0', '516116.0', '546911.0', '427608.0', '356299.0', '546946.0', '220007.0', '432498.0', '548673.0', '554759.0', '427648.0', '548401.0', '427607.0', '546926.0', '427601.0', '427633.0', '404268.0', '546913.0', '427659.0', '427628.0', '427627.0', '427605.0', '546950.0', '520985.0', '546902.0', '427668.0', '427604.0', '427674.0', '546907.0', '479087.0', '427427.0', '220010.0', '548655.0', '546912.0', '427612.0', '427653.0', '546901.0', '427635.0', '546910.0', '427669.0', '427677.0', '220020.0', '427641.0', '427661.0', '220098.0', '548440.0', '546904.0', '546974.0', '546968.0', '462729.0', '427609.0', '546927.0', '427901.0', '546969.0', '546941.0', '532356.0', '0.0', '546920.0', '546970.0', '546948.0', '554761.0', '220095.0', '427636.0', '427637.0', '546963.0', '546976.0', '546945.0', '220062.0', '440503.0', '427620.0', '427617.0', '220488.0', '427940.0', '522223.0', '546928.0', '220060.0', '427651.0', '546959.0', '417398.0', '427632.0', '546935.0', '548438.0', '546933.0', '546961.0', '546966.0', '426101.0', '220023.0', '546977.0', '546905.0', '548462.0', '427625.0', '546908.0', '546922.0', '520373.0', '546975.0', '546917.0', '559654.0', '552140.0', '546953.0', '427639.0', '427629.0', '220418.0', '400079.0', '479769.0', '546964.0', '220125.0', '220066.0', '427916.0', '408397.0', '220056.0', '546909.0', '427643.0', '548455.0', '546903.0', '548674.0', '510047.0', '404841.0', '546939.0', '548445.0', '487415.0', '546951.0', '220100.0', '445433.0', '479004.0', '559813.0', '546932.0', '220018.0', '546925.0', '546947.0', '414657.0', '220069.0', '546936.0', '557000.0', '220017.0', '432433.0', '220096.0', '404136.0', '427967.0', '481782.0', '356504.0', '427955.0', '546929.0', '518901.0', '419804.0', '220042.0', '405992.0', '546943.0'], 
                'Bank': ['SBER', '0', '[US] NEW WORLD IMMEDIATE ', 'VTB', 'ALFA-BANK', 'TINKOFF', '[IQ] JORDAN AHLI BANK', 'QIWI', 'OTKRITIE', 'POCHTA BANK', 'RNKB', 'PROMSVYAZBANK', 'RAIFFEISENBANK', 'CHINA AND SOUTH SEA BANK, LTD.', 'CREDIT UNION PAYMENT CENTER (LIMITED LIABILITY COMPANY)', 'ROSBANK', 'BANK LEVOBEREZHNY', 'CREDIT UNION CARD SERVICES, INC.', 'ISLAND F.C.U.', 'OJSC JSB ROSSIYA', 'URALSIB', 'GAZPROMBANK', 'JCB INTERNATIONAL CREDIT CARD CO., LTD.', 'GENBANK', 'MOSCOW BANK FOR RECONSTRUCTION AND DEVELOPMENT JSCB', 'AK BARS', '[RU] JSCB AVANGARD', 'HOME', '[RU] BANK ZENIT', '[RU] JSC RUSSIAN STANDARD BANK', '[RU] BANK SAINT PETERSBURG PLC', '[RU] URAL BANK FOR RECONSTRUCTION AND DEVELOPMENT JSC', 'BANCO DE DESARROLLO RURAL S.A. BANRURAL', '[RU] CREDIT UNION PAYMENT CENTER (LIMITED LIABILITY COMPANY)', '[RU] JSCB MOSCOW INDUSTRIAL BANK', 'NON-BANKING CREDIT ORG UNITED SETTLEMENT SYSTEM', '[RU] OJSC LETO BANK'], 
                'mask_person_addcontact': ['0', '1'], 
                'ActivityType': ['0', 'ТОРГОВЛЯ', 'ПРОМЫШЛЕННОСТЬ', 'ДРУГОЕ', 'СЕРВИС И УСЛУГИ', 'СТРОИТЕЛЬСТВО И НЕДВИЖИМОСТЬ', 'ТРАНСПОРТ', 'ГОСУДАРСТВЕННАЯ СЛУЖБА', 'НАУКА И ОБРАЗОВАНИЕ', 'МЕДИЦИНА', 'АРМИЯ', 'ОХРАННАЯ ДЕЯТЕЛЬНОСТЬ', 'ДОБЫВАЮЩИЙ СЕКТОР', 'ФИНАНСЫ, БАНКИ, СТРАХОВАНИЕ, КОНСАЛТИНГ', 'ИНФОРМАЦИОННЫЕ ТЕХНОЛОГИИ/ТЕЛЕКОММУНИКАЦИИ', 'КУЛЬТУРА И ИСКУССТВО', 'ТЭК'], 'Education': ['СРЕДНЕЕ СПЕЦИАЛЬНОЕ', 'ВЫСШЕЕ', 'СРЕДНЕЕ', 'НЕПОЛНОЕ ВЫСШЕЕ', 'НЕПОЛНОЕ СРЕДНЕЕ', 'ДРУГОЕ', '0'], 
                'Gender': ['0.0', '1.0'], 
                'LoanPurpose': ['0', 'НЕПРЕДВИДЕННЫЕ РАСХОДЫ', 'МЕДИЦИНСКИЕ УСЛУГИ', 'РЕМОНТ ДОМА ИЛИ АВТОМОБИЛЯ', 'ДРУГОЕ', 'ЕЖЕДНЕВНЫЕ РАСХОДЫ', 'ПОКУПКА БЫТОВОЙ ТЕХНИКИ И ЭЛЕКТРОНИКИ', 'ПОДАРКИ', 'ОБРАЗОВАНИЕ', 'БИЗНЕС', 'ПУТЕШЕСТВИЯ, ОТДЫХ'], 
                'MaritalStatus': ['0.0', '1.0', '3.0', '4.0', '2.0'], 
                'MonthlyIncome': ['50000.0', '45000.0', '35000.0', '30000.0', '40000.0', '60000.0', '25000.0', '70000.0', '80000.0', '55000.0', '65000.0', '20000.0', '75000.0', '100000.0', '90000.0', '85000.0', '120000.0', '28000.0', '38000.0', '32000.0', '15000.0', '27000.0', '42000.0', '150000.0', '37000.0', '48000.0', '47000.0', '36000.0', '95000.0', '43000.0', '56000.0', '52000.0', '23000.0', '34000.0', '26000.0', '18000.0', '46000.0', '24000.0', '22000.0', '110000.0', '54000.0', '39000.0', '29000.0', '33000.0', '57000.0', '58000.0', '10000.0', '67000.0', '68000.0', '130000.0', '78000.0', '53000.0', '200000.0', '17000.0', '21000.0', '31000.0', '72000.0', '62000.0', '44000.0', '140000.0', '49000.0', '41000.0', '63000.0', '87000.0', '16000.0', '250000.0', '19000.0', '98000.0', '180000.0', '64000.0', '12000.0', '76000.0', '71000.0', '125000.0', '89000.0', '86000.0', '105000.0', '69000.0', '115000.0', '51000.0', '160000.0', '59000.0', '73000.0', '66000.0', '300000.0', '79000.0', '170000.0', '74000.0', '14000.0', '97000.0', '5000.0', '13000.0', '350000.0', '96000.0', '450000.0', '88000.0', '135000.0', '83000.0', '82000.0', '77000.0', '500000.0', '92000.0', '84000.0', '93000.0', '61000.0', '190000.0', '145000.0', '27500.0', '400000.0', '37500.0', '28500.0', '32500.0', '800000.0', '3000.0', '94000.0', '11000.0', '600000.0', '220000.0', '22500.0', '47500.0', '38500.0', '42500.0', '8000.0', '700000.0', '25500.0', '195000.0', '24500.0', '23500.0', '35500.0', '650000.0', '18500.0', '34500.0', '26500.0', '185000.0', '240000.0', '6000.0', '7000.0', '230000.0', '2000.0', '45500.0', '112000.0', '4000.0', '81000.0', '45.0', '165000.0', '210000.0', '29500.0', '12500.0', '35.0', '750000.0', '43500.0', '48500.0', '102000.0', '175000.0', '17500.0', '31500.0', '91000.0', '155000.0', '99000.0', '9000.0', '900000.0', '36500.0', '21500.0', '0.0', '550000.0', '280000.0', '46500.0', '60.0', '16500.0', '19500.0', '2500.0', '50.0', '40.0', '103000.0', '1000.0', '108000.0', '49500.0', '30.0', '25.0', '45600.0', '3500.0', '28600.0', '15500.0', '33500.0', '35600.0', '104000.0', '14500.0', '44500.0', '56700.0', '39500.0', '52500.0', '27800.0', '107000.0', '20500.0', '270000.0', '1000000.0', '320000.0', '13500.0', '35700.0', '45800.0', '850000.0', '28900.0', '124000.0', '45700.0', '26700.0', '123000.0', '42300.0', '1200000.0'], 
                'Post': ['РАБОЧИЙ', 'СЛУЖАЩИЙ / СПЕЦИАЛИСТ', '0', 'НАЧАЛЬНИК / РУКОВОДИТЕЛЬ', 'РУКОВОДИТЕЛЬ КОМПАНИИ', 'ВОЕННЫЙ', 'ДРУГОЕ', 'МЕДСЕСТРА/МЕДБРАТ', 'РЯДОВОЙ', 'ГЛАВНЫЙ БУХГАЛТЕР', 'ОФИЦЕР', 'ВРАЧ', 'ФАРМАЦЕВТ'], 
                'OrganizationPhone_group': ['1.0', '4.0', '2.0', '3.0']}

# %%
# Функция для замены значений в столбце
def replace_with_others(column, values_to_keep):
    return column.apply(lambda x: x if x in values_to_keep else 'others')

# Применяем функцию к каждому столбцу
for column, values_to_keep in columns_dict.items():
    df[column] = replace_with_others(df[column], values_to_keep)

# %% [markdown]
# <a id='Энкодинг'></a>
# ## Энкодинг

# %%
with open(f'Z:\\Скоринг –Олег\\Подготовка фичей\\новое\\train_test\\anketa\\anketa_woe_encoder.pickle', 'rb') as file:
    anketa_woe_encoder = pickle.load(file)
    
with open(f'Z:\\Скоринг –Олег\\Подготовка фичей\\новое\\train_test\\dop\\dop_woe_encoder.pickle', 'rb') as file:
    dop_woe_encoder = pickle.load(file)

# %%
attribs_anketa = ['ActivityType',
 'Education',
 'Gender',
 'LoanPurpose',
 'MaritalStatus',
 'MonthlyIncome',
 'Post',
 'OrganizationPhone_group']

attribs_dop = [
 'InsurancePolicy',
 'VerifiedByESIA',
 'EMailVerified',
 'RegisterSameFact',
 'StoreName',
 'mobile',
 'PingTreeLead',
 'Bin',
 'Bank',
 'mask_person_addcontact']

# %%
df[attribs_anketa] = anketa_woe_encoder.transform(df[attribs_anketa])

df[attribs_dop] = dop_woe_encoder.transform(df[attribs_dop])

# %%
df
# Out:
#    ScoringAmount  Score  ActivityType  Education    Gender  LoanPurpose  \
# 0         5900.0  500.0     -0.018936   0.206511  0.137713    -0.020592
#
#    MaritalStatus  MonthlyIncome      Post  InsurancePolicy  ...  \
# 0       0.073894       0.046307  0.155843         0.154436  ...
#
#    NextPayoutSum_avg_avg_all_noactive_all  \
# 0                             2752.941176
#
#    Regularity_ohe2_sum_sum_micro_noactive_6m  \
# 0                                        0.0
#
#    Regularity_ohe2_sum_max_micro_noactive_all  \
# 0                                         0.0
#
#    Regularity_ohe3_sum_sum_all_noactive_all  \
# 0                                       0.0
#
#    Regularity_ohe3_avg_sum_micro_noactive_1y  \
# 0                                        0.0
#
#    NextPayoutSum_sum_max_all_noactive_all  \
# 0                                 21600.0
#
#    PercentNextPayoutSum_sum_max_all_noactive_all  \
# 0                                         5702.4
#
# ...

# %% [markdown]
# <a id='Обработка-БКИ'></a>
# # Обработка БКИ

# %%
info_dict = {'Название таблицы': ['pay_discipline',  'payment_terms',  'ContractAmount',  'Summary',  'ContractChanges',  'Court',  'Deal',  'DebtCurrent',  'FullCostPercent',  'JointDebtors',  'Paymeanmfo',  'Debt',  'Payments'],
                 'столбцы для РСА' : ["['A_sum_micro_noactive_all',\n 'len_str_sum_micro_noactive_6m',\n '0_sum_all_noactive_all',\n '2_sum_all_noactive_all',\n '1_max_all_noactive_1y',\n 'last_0_sum_micro_noactive_6m',\n '0_avg_micro_noactive_all',\n 'len_str_max_micro_noactive_1y',\n 'len_str_avg_all_noactive_6m',\n 'last_dash_sum_all_noactive_1y',\n 'C_avg_micro_noactive_all',\n '2_sum_all_noactive_6m',\n 'C_max_all_noactive_6m',\n 'last_C_sum_all_noactive_all',\n 'S_max_all_noactive_all',\n 'len_str_sum_all_noactive_all',\n 'C_avg_micro_noactive_6m',\n 'dash_max_all_noactive_1y',\n 'A_max_all_noactive_all',\n 'len_str_max_all_noactive_all',\n '0_avg_all_noactive_1y',\n 'dash_max_micro_noactive_all',\n 'len_str_avg_micro_noactive_all',\n '0_max_all_noactive_all',\n '1_max_all_noactive_all',\n 'len_str_avg_all_noactive_1y',\n 'C_max_all_noactive_all',\n 'len_str_max_micro_noactive_all',\n '0_max_all_noactive_1y',\n 'dash_max_micro_noactive_6m',\n '2_max_micro_noactive_all',\n 'len_str_max_all_noactive_6m',\n '2_max_all_noactive_all',\n '1_max_micro_noactive_all',\n '0_avg_all_noactive_all',\n 'C_max_micro_noactive_1y',\n '0_max_micro_noactive_1y',\n 'dash_sum_micro_noactive_all',\n '0_max_all_noactive_6m',\n '3_max_all_noactive_all',\n 'len_str_max_micro_noactive_6m',\n '0_max_micro_noactive_all']",
                                      "['PaymentTerms_count_all_noactive_6m',\n 'Regularity_ohe99_sum_sum_all_noactive_1y',\n 'NextPayoutSum_sum_sum_all_noactive_all',\n 'Regularity_ohe1_sum_sum_micro_noactive_all',\n 'Regularity_ohe3_avg_max_all_noactive_6m',\n 'NextPayoutSum_avg_max_all_noactive_1y',\n 'NextPayoutSum_max_avg_micro_noactive_6m',\n 'PercentNextPayoutSum_min_avg_all_noactive_6m',\n 'NextPayoutSum_sum_max_micro_noactive_6m',\n 'PercentNextPayoutSum_avg_max_micro_noactive_1y',\n 'NextPayoutSum_max_avg_all_noactive_1y',\n 'Regularity_ohe3_avg_sum_all_noactive_6m',\n 'PercentNextPayoutSum_avg_sum_all_noactive_all',\n 'NextPayoutSum_avg_avg_all_noactive_all',\n 'Regularity_ohe2_sum_sum_micro_noactive_6m',\n 'Regularity_ohe2_sum_max_micro_noactive_all',\n 'Regularity_ohe3_sum_sum_all_noactive_all',\n 'Regularity_ohe3_avg_sum_micro_noactive_1y',\n 'NextPayoutSum_sum_max_all_noactive_all',\n 'PercentNextPayoutSum_sum_max_all_noactive_all',\n 'PercentNextPayoutSum_min_avg_all_noactive_all',\n 'NextPayoutSum_min_max_all_noactive_6m']",
                                      "['ContractAmountCurrencyIsRUR_sum_all_noactive_all',\n 'ContractAmountSum_avg_all_noactive_1y',\n 'ContractAmountSum_avg_all_noactive_all',\n 'ContractAmountSum_min_all_noactive_all',\n 'ContractAmountSum_max_all_noactive_all',\n 'ContractAmountSum_max_micro_noactive_6m',\n 'ContractAmountSum_max_all_noactive_6m',\n 'ContractAmountSum_sum_all_noactive_1y',\n 'ContractAmountSum_avg_micro_noactive_all',\n 'ContractAmountSum_max_micro_noactive_all',\n 'ContractAmountSum_min_all_noactive_6m',\n 'ContractAmountSum_sum_all_noactive_all']",
                                      "['Delay90_sum_all_noactive_all',\n 'CredMaxOverdue_max_all_noactive_all',\n 'Delay30_max_all_noactive_all',\n 'CredMaxOverdue_max_all_noactive_6m',\n 'CredMaxOverdue_avg_all_noactive_all',\n 'Delay30_sum_all_noactive_1y',\n 'CredMaxOverdue_sum_all_noactive_6m',\n 'DelayMore_sum_all_noactive_all',\n 'CredMaxOverdue_max_all_noactive_1y',\n 'CredMaxOverdue_avg_all_noactive_6m',\n 'Delay5_sum_all_noactive_all',\n 'Delay60_sum_all_noactive_all',\n 'CredMaxOverdue_avg_all_noactive_1y']",
                                      "['ChangeType_ohe3_sum_max_all_noactive_6m',\n 'ChangeSign_sum_sum_micro_noactive_6m',\n 'ChangeType_ohe1_sum_max_all_noactive_1y',\n 'ChangeSign_sum_max_all_noactive_all',\n 'ContractChanges_count_micro_noactive_all',\n 'ChangeType_ohe3_sum_min_micro_noactive_1y',\n 'ChangeSign_sum_avg_all_noactive_6m',\n 'ChangeType_ohe3_sum_avg_micro_noactive_1y',\n 'ChangeType_ohe3_sum_avg_all_noactive_all',\n 'ChangeType_ohe3_sum_max_all_noactive_1y',\n 'ChangeSign_sum_avg_micro_noactive_all',\n 'ChangeType_ohe3_sum_max_micro_noactive_all']",
                                      "['CourtDisputeCase_oheNULL_sum_micro_noactive_1y',\n 'CourtSign_oheNULL_sum_micro_noactive_all']",
                                      "['DealCredOwnerTypeIsNull_sum_micro_noactive_1y',\n 'DealPurposeID_ohe99_sum_micro_noactive_1y',\n 'DealDays_avg_micro_noactive_6m',\n 'DealDays_min_all_noactive_all',\n 'Deal_count_all_noactive_all',\n 'DealDays_sum_all_noactive_1y',\n 'DealDays_max_micro_noactive_all',\n 'DealPurposeID_ohe15_sum_all_noactive_all',\n 'DealDays_sum_all_noactive_all',\n 'DealDays_max_all_noactive_6m',\n 'DealDays_max_micro_noactive_6m',\n 'DealDays_avg_all_noactive_6m',\n 'DealDays_avg_all_noactive_all',\n 'DealType_ohe1_sum_all_noactive_1y',\n 'DealType_ohe5_sum_all_noactive_all']",
                                      "['DebtCurrentOpSum_max_min_all_noactive_6m',\n 'DebtCurrentPercentSum_max_avg_all_noactive_1y',\n 'DebtCurrentOtherSum_avg_avg_all_noactive_1y',\n 'DebtCurrentDebtSum_sum_avg_micro_noactive_6m',\n 'DebtCurrentDebtSum_avg_min_micro_noactive_1y',\n 'DebtCurrentDebtSum_min_max_micro_noactive_all',\n 'DebtCurrentPercentSum_min_avg_micro_noactive_all',\n 'DebtCurrentOtherSum_min_max_all_noactive_all',\n 'DebtCurrentPercentSum_min_max_micro_noactive_all',\n 'DebtCurrentOpSum_avg_min_all_noactive_all',\n 'DebtCurrentOpSum_max_sum_all_noactive_1y',\n 'DebtCurrentOpSum_avg_max_all_noactive_6m',\n 'DebtCurrentPercentSum_max_max_all_noactive_1y',\n 'DebtCurrentOtherSum_max_max_all_noactive_6m',\n 'DebtCurrentDebtSum_max_max_all_noactive_all',\n 'DebtCurrentDebtSum_min_avg_all_noactive_1y',\n 'DebtCurrentOtherSum_sum_avg_all_noactive_6m',\n 'DebtCurrentOtherSum_min_max_all_noactive_1y',\n 'DebtCurrentOtherSum_avg_avg_all_noactive_all']",
                                      "['ContractEndDateDaysFromDeal_min_all_noactive_all',\n 'ContractEndDateDaysFromDeal_avg_micro_noactive_all',\n 'ContractEndReason_ohe1_sum_micro_noactive_6m',\n 'FullCostSum_max_all_noactive_6m',\n 'FullCostSum_avg_all_noactive_1y',\n 'AveragePaymentSum_sum_all_noactive_6m',\n 'FullCostSum_sum_micro_noactive_1y',\n 'AveragePaymentSum_avg_all_noactive_6m',\n 'FullCostPercent_min_micro_noactive_1y',\n 'ContractEndDateDaysFromDeal_max_all_noactive_all',\n 'FullCostPercent_avg_all_noactive_6m',\n 'ContractEndReason_ohe1_sum_all_noactive_all',\n 'FullCostSum_min_all_noactive_1y',\n 'ContractEndReason_oheNULL_sum_all_noactive_all',\n 'AveragePaymentSum_max_all_noactive_1y',\n 'AveragePaymentSum_max_all_noactive_6m',\n 'FullCostSum_avg_micro_noactive_1y',\n 'FullCostSum_sum_all_noactive_1y',\n 'FullCostSum_max_all_noactive_all',\n 'ContractEndDateDaysFromDeal_sum_all_noactive_all',\n 'FullCostPercent_min_all_noactive_all',\n 'ContractEndDateDaysFromDeal_max_all_noactive_1y',\n 'FullCostSum_max_micro_noactive_1y',\n 'CredStartDebtDaysFromDeal_sum_all_noactive_all',\n 'AveragePaymentSum_max_micro_noactive_all',\n 'FullCostPercent_min_micro_noactive_all',\n 'FullCostSum_avg_all_noactive_all',\n 'CredStartDebtDaysFromDeal_max_all_noactive_1y',\n 'ContractEndDateDaysFromDeal_max_micro_noactive_all',\n 'AveragePaymentSum_avg_all_noactive_all',\n 'ContractEndDateDaysFromDeal_max_all_noactive_6m',\n 'AveragePaymentSum_avg_micro_noactive_all',\n 'AveragePaymentSum_sum_all_noactive_all',\n 'ContractEndDateDaysFromDeal_avg_all_noactive_all',\n 'CredStartDebtDaysFromDeal_max_all_noactive_all',\n 'FullCostPercent_avg_micro_noactive_all',\n 'FullCostPercent_min_all_noactive_1y',\n 'AveragePaymentSum_avg_all_noactive_1y',\n 'ContractEndDateDaysFromDeal_sum_micro_noactive_all']",
                                      "['JointDebtors_count_micro_noactive_1y', 'JointDebtors_count_all_noactive_all']",
                                      "['n1007_avg_all_noactive_all',\n 'n1002_max_micro_noactive_1y',\n 'n1005_avg_micro_noactive_6m',\n 'n1004_sum_all_noactive_6m',\n 'n1002_sum_micro_noactive_1y',\n 'n1005_min_all_noactive_6m',\n 'n1006_max_micro_noactive_1y',\n 'n1006_avg_micro_noactive_6m',\n 'n1007_max_all_noactive_all',\n 'n1001_min_all_noactive_all',\n 'n1002_avg_all_noactive_all',\n 'n1001_max_all_noactive_1y',\n 'n1006_max_micro_noactive_all',\n 'n1006_max_all_noactive_1y',\n 'n1002_min_all_noactive_1y',\n 'n1002_sum_all_noactive_all',\n 'n1005_min_micro_noactive_all',\n 'n1000_count_n1000_2_all_noactive_all',\n 'n1004_avg_all_noactive_1y',\n 'n1006_min_micro_noactive_6m',\n 'n1003_sum_micro_noactive_6m',\n 'n1004_max_all_noactive_1y',\n 'n1004_avg_micro_noactive_all',\n 'n1003_avg_all_noactive_all',\n 'n1002_max_all_noactive_1y',\n 'n1002_max_all_noactive_6m',\n 'n1002_avg_micro_noactive_all',\n 'n1000_count_n1000_0_micro_noactive_1y',\n 'n1004_max_all_noactive_all',\n 'n1000_count_n1000_0_micro_noactive_all',\n 'n1005_avg_all_noactive_1y',\n 'n1000_count_n1000_1_all_noactive_all',\n 'n1004_avg_micro_noactive_6m',\n 'n1005_avg_micro_noactive_all',\n 'n1006_min_all_noactive_all',\n 'n1005_min_all_noactive_all']",
                                      "['DebtSignCalcLastPayout_cnt0_all_noactive_all',\n 'DebtFirstSum_max_min_all_noactive_1y',\n 'DebtFirstSum_max_min_micro_noactive_all',\n 'DebtSum_min_max_all_noactive_1y',\n 'DebtFirstSum_sum_max_all_noactive_6m',\n 'DebtSum_max_max_micro_noactive_6m',\n 'DebtSum_min_sum_micro_noactive_1y',\n 'DebtSum_min_avg_micro_noactive_6m',\n 'DebtPercentSum_sum_avg_all_noactive_all',\n 'DebtFirstSum_min_sum_all_noactive_1y',\n 'DebtOtherSum_min_sum_micro_noactive_6m',\n 'DebtSum_min_sum_all_noactive_all',\n 'DebtOtherSum_sum_max_all_noactive_1y',\n 'DebtOtherSum_avg_sum_all_noactive_all',\n 'DebtPercentSum_avg_max_micro_noactive_6m',\n 'DebtOtherSum_max_avg_all_noactive_1y',\n 'DebtOtherSum_max_avg_all_noactive_6m',\n 'DebtSum_sum_avg_all_noactive_all',\n 'DebtOtherSum_avg_max_all_noactive_6m',\n 'DebtPercentSum_sum_avg_micro_noactive_all',\n 'DebtFirstSum_min_min_all_noactive_all',\n 'debt_count_all_noactive_6m',\n 'DebtFirstSum_avg_sum_all_noactive_all',\n 'DebtPercentSum_max_avg_all_noactive_1y',\n 'DebtFirstSum_max_max_all_noactive_all',\n 'DebtPercentSum_avg_avg_micro_noactive_6m',\n 'DebtOtherSum_avg_avg_all_noactive_all',\n 'DebtFirstSum_min_max_micro_noactive_all',\n 'DebtPercentSum_max_max_micro_noactive_all',\n 'DebtSum_max_max_micro_noactive_all',\n 'DebtOtherSum_min_sum_micro_noactive_all',\n 'DebtSum_avg_avg_micro_noactive_all',\n 'DebtOtherSum_sum_avg_micro_noactive_6m',\n 'DebtOtherSum_avg_avg_micro_noactive_all',\n 'DebtFirstSum_avg_avg_all_noactive_all',\n 'DebtOtherSum_sum_avg_micro_noactive_1y']",
                                      "['PaidOpSum_sum_max_micro_noactive_6m',\n 'PaidPercentSum_max_max_all_noactive_all',\n 'LastPayoutOtherSum_max_sum_micro_noactive_6m',\n 'PaidSum_max_sum_all_noactive_1y',\n 'PaidOtherSum_max_avg_micro_noactive_1y',\n 'PaidPercentSum_max_sum_micro_noactive_6m',\n 'LastPayoutOtherSum_max_avg_all_noactive_6m',\n 'LastPayoutOtherSum_min_avg_micro_noactive_all',\n 'LastPayoutOtherSum_max_avg_all_noactive_1y',\n 'PaidSum_min_avg_micro_noactive_all',\n 'PaidOpSum_min_max_micro_noactive_all',\n 'LastPayoutOtherSum_min_avg_all_noactive_all',\n 'LastPayoutPercentSum_avg_min_micro_noactive_1y',\n 'LastPayoutPercentSum_min_avg_micro_noactive_1y',\n 'Payments_count_all_noactive_all',\n 'PaidOtherSum_avg_sum_micro_noactive_6m',\n 'PaidOtherSum_max_max_all_noactive_all',\n 'OverdueDay_avg_max_all_noactive_1y',\n 'LastPayoutOpSum_max_avg_all_noactive_all',\n 'PaidSum_sum_avg_all_noactive_all',\n 'PaidPercentSum_max_max_all_noactive_6m',\n 'PaidOtherSum_avg_avg_all_noactive_1y',\n 'LastPayoutSum_avg_avg_micro_noactive_all',\n 'PaidOtherSum_sum_sum_micro_noactive_all',\n 'SizePaymentsTypeID_ohe1_avg_sum_micro_noactive_1y',\n 'SizePaymentsTypeID_ohe3_avg_sum_micro_noactive_1y',\n 'PaidOpSum_min_avg_micro_noactive_1y',\n 'DeadlineTypeID_ohe3_sum_sum_micro_noactive_6m',\n 'LastPayoutOpSum_min_sum_all_noactive_all',\n 'LastPayoutPercentSum_sum_max_micro_noactive_6m',\n 'PaidOtherSum_sum_sum_all_noactive_1y',\n 'LastPayoutOtherSum_avg_max_all_noactive_1y',\n 'LastPayoutSum_sum_max_all_noactive_6m',\n 'OverdueDay_min_max_all_noactive_all',\n 'PaidOpSum_max_max_all_noactive_1y',\n 'LastPayoutOtherSum_min_avg_micro_noactive_1y',\n 'LastPayoutPercentSum_min_max_all_noactive_1y',\n 'LastPayoutSum_max_max_micro_noactive_1y',\n 'LastPayoutOpSum_max_min_all_noactive_1y',\n 'PaidOtherSum_max_avg_all_noactive_all',\n 'LastPayoutSum_avg_avg_all_noactive_1y',\n 'LastPayoutOtherSum_min_max_all_noactive_6m',\n 'PaidOpSum_sum_max_all_noactive_6m',\n 'LastPayoutOpSum_min_min_micro_noactive_6m',\n 'OverdueDay_sum_sum_micro_noactive_6m',\n 'OverdueDay_sum_avg_all_noactive_all',\n 'LastPayoutSum_min_max_all_noactive_all',\n 'PaidPercentSum_sum_avg_all_noactive_1y',\n 'PaidOtherSum_min_max_all_noactive_6m',\n 'PaidPercentSum_min_max_all_noactive_1y',\n 'PaidPercentSum_sum_avg_micro_noactive_6m',\n 'PaidOpSum_max_avg_all_noactive_6m',\n 'LastPayoutOtherSum_min_sum_all_noactive_all',\n 'PaidOpSum_max_max_all_noactive_all',\n 'LastPayoutSum_min_max_all_noactive_1y',\n 'SizePaymentsTypeID_ohe2_avg_sum_all_noactive_all',\n 'OverdueDay_min_max_micro_noactive_all',\n 'PaidSum_min_avg_all_noactive_1y',\n 'PaidPercentSum_min_avg_micro_noactive_all',\n 'PaidOtherSum_max_avg_all_noactive_6m',\n 'OverdueDay_sum_avg_micro_noactive_all',\n 'PaidOtherSum_max_avg_micro_noactive_all',\n 'PaidPercentSum_avg_avg_all_noactive_all']"],
                 'оставшиеся столбцы': ["['A_sum_micro_noactive_all',\n 'len_str_sum_micro_noactive_6m',\n '0_sum_all_noactive_all',\n '2_sum_all_noactive_all',\n '1_max_all_noactive_1y',\n 'last_0_sum_micro_noactive_6m',\n '0_avg_micro_noactive_all',\n 'len_str_max_micro_noactive_1y',\n 'len_str_avg_all_noactive_6m',\n 'last_dash_sum_all_noactive_1y',\n 'C_avg_micro_noactive_all',\n '2_sum_all_noactive_6m',\n 'C_max_all_noactive_6m',\n 'last_C_sum_all_noactive_all',\n 'S_max_all_noactive_all',\n 'len_str_sum_all_noactive_all',\n 'C_avg_micro_noactive_6m',\n 'dash_max_all_noactive_1y',\n 'A_max_all_noactive_all',\n 'len_str_max_all_noactive_all',\n '0_avg_all_noactive_1y',\n 'dash_max_micro_noactive_all',\n 'len_str_avg_micro_noactive_all',\n '0_max_all_noactive_all',\n '1_max_all_noactive_all',\n 'len_str_avg_all_noactive_1y',\n 'C_max_all_noactive_all',\n 'len_str_max_micro_noactive_all',\n '0_max_all_noactive_1y',\n 'dash_max_micro_noactive_6m',\n '2_max_micro_noactive_all',\n 'len_str_max_all_noactive_6m',\n '2_max_all_noactive_all',\n '1_max_micro_noactive_all',\n '0_avg_all_noactive_all',\n 'C_max_micro_noactive_1y',\n '0_max_micro_noactive_1y',\n 'dash_sum_micro_noactive_all',\n '0_max_all_noactive_6m',\n '3_max_all_noactive_all',\n 'len_str_max_micro_noactive_6m',\n '0_max_micro_noactive_all',\n 'pay_discipline_10_3',\n 'pay_discipline_10_4',\n 'pay_discipline_10_5',\n 'pay_discipline_10_6',\n 'pay_discipline_10_7',\n 'pay_discipline_10_8',\n 'pay_discipline_10_9']",
                                      "[ 'PaymentTerms_count_all_noactive_6m',\n 'Regularity_ohe99_sum_sum_all_noactive_1y',\n 'NextPayoutSum_sum_sum_all_noactive_all',\n 'Regularity_ohe1_sum_sum_micro_noactive_all',\n 'Regularity_ohe3_avg_max_all_noactive_6m',\n 'NextPayoutSum_avg_max_all_noactive_1y',\n 'NextPayoutSum_max_avg_micro_noactive_6m',\n 'PercentNextPayoutSum_min_avg_all_noactive_6m',\n 'NextPayoutSum_sum_max_micro_noactive_6m',\n 'PercentNextPayoutSum_avg_max_micro_noactive_1y',\n 'NextPayoutSum_max_avg_all_noactive_1y',\n 'Regularity_ohe3_avg_sum_all_noactive_6m',\n 'PercentNextPayoutSum_avg_sum_all_noactive_all',\n 'NextPayoutSum_avg_avg_all_noactive_all',\n 'Regularity_ohe2_sum_sum_micro_noactive_6m',\n 'Regularity_ohe2_sum_max_micro_noactive_all',\n 'Regularity_ohe3_sum_sum_all_noactive_all',\n 'Regularity_ohe3_avg_sum_micro_noactive_1y',\n 'NextPayoutSum_sum_max_all_noactive_all',\n 'PercentNextPayoutSum_sum_max_all_noactive_all',\n 'PercentNextPayoutSum_min_avg_all_noactive_all',\n 'NextPayoutSum_min_max_all_noactive_6m',\n 'payment_terms_10_1',\n 'payment_terms_10_3',\n 'payment_terms_10_4',\n 'payment_terms_10_6',\n 'payment_terms_10_7',\n 'payment_terms_10_8',\n 'payment_terms_10_9']",
                                      "['ContractAmountCurrencyIsRUR_sum_all_noactive_all',\n 'ContractAmountSum_avg_all_noactive_1y',\n 'ContractAmountSum_avg_all_noactive_all',\n 'ContractAmountSum_min_all_noactive_all',\n 'ContractAmountSum_max_all_noactive_all',\n 'ContractAmountSum_max_micro_noactive_6m',\n 'ContractAmountSum_max_all_noactive_6m',\n 'ContractAmountSum_sum_all_noactive_1y',\n 'ContractAmountSum_avg_micro_noactive_all',\n 'ContractAmountSum_max_micro_noactive_all',\n 'ContractAmountSum_min_all_noactive_6m',\n 'ContractAmountSum_sum_all_noactive_all',\n 'ContractAmount_10_2',\n 'ContractAmount_10_3',\n 'ContractAmount_10_5',\n 'ContractAmount_10_6',\n 'ContractAmount_10_7',\n 'ContractAmount_10_8',\n 'ContractAmount_10_9']",
                                      "[ 'Delay90_sum_all_noactive_all',\n 'CredMaxOverdue_max_all_noactive_all',\n 'Delay30_max_all_noactive_all',\n 'CredMaxOverdue_max_all_noactive_6m',\n 'CredMaxOverdue_avg_all_noactive_all',\n 'Delay30_sum_all_noactive_1y',\n 'CredMaxOverdue_sum_all_noactive_6m',\n 'DelayMore_sum_all_noactive_all',\n 'CredMaxOverdue_max_all_noactive_1y',\n 'CredMaxOverdue_avg_all_noactive_6m',\n 'Delay5_sum_all_noactive_all',\n 'Delay60_sum_all_noactive_all',\n 'CredMaxOverdue_avg_all_noactive_1y',\n 'Summary_10_0',\n 'Summary_10_1',\n 'Summary_10_2',\n 'Summary_10_3',\n 'Summary_10_4',\n 'Summary_10_5',\n 'Summary_10_6',\n 'Summary_10_7',\n 'Summary_10_8',\n 'Summary_10_9']",
                                      "[ 'ChangeType_ohe3_sum_max_all_noactive_6m',\n 'ChangeSign_sum_sum_micro_noactive_6m',\n 'ChangeType_ohe1_sum_max_all_noactive_1y',\n 'ChangeSign_sum_max_all_noactive_all',\n 'ContractChanges_count_micro_noactive_all',\n 'ChangeType_ohe3_sum_min_micro_noactive_1y',\n 'ChangeSign_sum_avg_all_noactive_6m',\n 'ChangeType_ohe3_sum_avg_micro_noactive_1y',\n 'ChangeType_ohe3_sum_avg_all_noactive_all',\n 'ChangeType_ohe3_sum_max_all_noactive_1y',\n 'ChangeSign_sum_avg_micro_noactive_all',\n 'ChangeType_ohe3_sum_max_micro_noactive_all',\n 'ContractChanges_10_3',\n 'ContractChanges_10_4',\n 'ContractChanges_10_5',\n 'ContractChanges_10_6',\n 'ContractChanges_10_7',\n 'ContractChanges_10_8',\n 'ContractChanges_10_9']",
                                      "[ 'CourtDisputeCase_oheNULL_sum_micro_noactive_1y',\n 'CourtSign_oheNULL_sum_micro_noactive_all',\n 'Court_2_1']",
                                      "[ 'DealCredOwnerTypeIsNull_sum_micro_noactive_1y',\n 'DealPurposeID_ohe99_sum_micro_noactive_1y',\n 'DealDays_avg_micro_noactive_6m',\n 'DealDays_min_all_noactive_all',\n 'Deal_count_all_noactive_all',\n 'DealDays_sum_all_noactive_1y',\n 'DealDays_max_micro_noactive_all',\n 'DealPurposeID_ohe15_sum_all_noactive_all',\n 'DealDays_sum_all_noactive_all',\n 'DealDays_max_all_noactive_6m',\n 'DealDays_max_micro_noactive_6m',\n 'DealDays_avg_all_noactive_6m',\n 'DealDays_avg_all_noactive_all',\n 'DealType_ohe1_sum_all_noactive_1y',\n 'DealType_ohe5_sum_all_noactive_all',\n 'Deal_10_0',\n 'Deal_10_1',\n 'Deal_10_2',\n 'Deal_10_3',\n 'Deal_10_4',\n 'Deal_10_5',\n 'Deal_10_6',\n 'Deal_10_7',\n 'Deal_10_8',\n 'Deal_10_9']",
                                      "['DebtCurrentOpSum_max_min_all_noactive_6m',\n 'DebtCurrentPercentSum_max_avg_all_noactive_1y',\n 'DebtCurrentOtherSum_avg_avg_all_noactive_1y',\n 'DebtCurrentDebtSum_sum_avg_micro_noactive_6m',\n 'DebtCurrentDebtSum_avg_min_micro_noactive_1y',\n 'DebtCurrentDebtSum_min_max_micro_noactive_all',\n 'DebtCurrentPercentSum_min_avg_micro_noactive_all',\n 'DebtCurrentOtherSum_min_max_all_noactive_all',\n 'DebtCurrentPercentSum_min_max_micro_noactive_all',\n 'DebtCurrentOpSum_avg_min_all_noactive_all',\n 'DebtCurrentOpSum_max_sum_all_noactive_1y',\n 'DebtCurrentOpSum_avg_max_all_noactive_6m',\n 'DebtCurrentPercentSum_max_max_all_noactive_1y',\n 'DebtCurrentOtherSum_max_max_all_noactive_6m',\n 'DebtCurrentDebtSum_max_max_all_noactive_all',\n 'DebtCurrentDebtSum_min_avg_all_noactive_1y',\n 'DebtCurrentOtherSum_sum_avg_all_noactive_6m',\n 'DebtCurrentOtherSum_min_max_all_noactive_1y',\n 'DebtCurrentOtherSum_avg_avg_all_noactive_all',\n 'DebtCurrent_10_0',\n 'DebtCurrent_10_1',\n 'DebtCurrent_10_5',\n 'DebtCurrent_10_6',\n 'DebtCurrent_10_7',\n 'DebtCurrent_10_8',\n 'DebtCurrent_10_9']",
                                      "['ContractEndDateDaysFromDeal_min_all_noactive_all',\n 'ContractEndDateDaysFromDeal_avg_micro_noactive_all',\n 'ContractEndReason_ohe1_sum_micro_noactive_6m',\n 'FullCostSum_max_all_noactive_6m',\n 'FullCostSum_avg_all_noactive_1y',\n 'AveragePaymentSum_sum_all_noactive_6m',\n 'FullCostSum_sum_micro_noactive_1y',\n 'AveragePaymentSum_avg_all_noactive_6m',\n 'FullCostPercent_min_micro_noactive_1y',\n 'ContractEndDateDaysFromDeal_max_all_noactive_all',\n 'FullCostPercent_avg_all_noactive_6m',\n 'ContractEndReason_ohe1_sum_all_noactive_all',\n 'FullCostSum_min_all_noactive_1y',\n 'ContractEndReason_oheNULL_sum_all_noactive_all',\n 'AveragePaymentSum_max_all_noactive_1y',\n 'AveragePaymentSum_max_all_noactive_6m',\n 'FullCostSum_avg_micro_noactive_1y',\n 'FullCostSum_sum_all_noactive_1y',\n 'FullCostSum_max_all_noactive_all',\n 'ContractEndDateDaysFromDeal_sum_all_noactive_all',\n 'FullCostPercent_min_all_noactive_all',\n 'ContractEndDateDaysFromDeal_max_all_noactive_1y',\n 'FullCostSum_max_micro_noactive_1y',\n 'CredStartDebtDaysFromDeal_sum_all_noactive_all',\n 'AveragePaymentSum_max_micro_noactive_all',\n 'FullCostPercent_min_micro_noactive_all',\n 'FullCostSum_avg_all_noactive_all',\n 'CredStartDebtDaysFromDeal_max_all_noactive_1y',\n 'ContractEndDateDaysFromDeal_max_micro_noactive_all',\n 'AveragePaymentSum_avg_all_noactive_all',\n 'ContractEndDateDaysFromDeal_max_all_noactive_6m',\n 'AveragePaymentSum_avg_micro_noactive_all',\n 'AveragePaymentSum_sum_all_noactive_all',\n 'ContractEndDateDaysFromDeal_avg_all_noactive_all',\n 'CredStartDebtDaysFromDeal_max_all_noactive_all',\n 'FullCostPercent_avg_micro_noactive_all',\n 'FullCostPercent_min_all_noactive_1y',\n 'AveragePaymentSum_avg_all_noactive_1y',\n 'ContractEndDateDaysFromDeal_sum_micro_noactive_all',\n 'FullCostPercent_10_1',\n 'FullCostPercent_10_2',\n 'FullCostPercent_10_3',\n 'FullCostPercent_10_4',\n 'FullCostPercent_10_5',\n 'FullCostPercent_10_6',\n 'FullCostPercent_10_7',\n 'FullCostPercent_10_8',\n 'FullCostPercent_10_9']",
                                      "[ 'JointDebtors_count_micro_noactive_1y',\n 'JointDebtors_count_all_noactive_all',\n 'JointDebtors_2_1']",
                                      "[ 'n1007_avg_all_noactive_all',\n 'n1002_max_micro_noactive_1y',\n 'n1005_avg_micro_noactive_6m',\n 'n1004_sum_all_noactive_6m',\n 'n1002_sum_micro_noactive_1y',\n 'n1005_min_all_noactive_6m',\n 'n1006_max_micro_noactive_1y',\n 'n1006_avg_micro_noactive_6m',\n 'n1007_max_all_noactive_all',\n 'n1001_min_all_noactive_all',\n 'n1002_avg_all_noactive_all',\n 'n1001_max_all_noactive_1y',\n 'n1006_max_micro_noactive_all',\n 'n1006_max_all_noactive_1y',\n 'n1002_min_all_noactive_1y',\n 'n1002_sum_all_noactive_all',\n 'n1005_min_micro_noactive_all',\n 'n1000_count_n1000_2_all_noactive_all',\n 'n1004_avg_all_noactive_1y',\n 'n1006_min_micro_noactive_6m',\n 'n1003_sum_micro_noactive_6m',\n 'n1004_max_all_noactive_1y',\n 'n1004_avg_micro_noactive_all',\n 'n1003_avg_all_noactive_all',\n 'n1002_max_all_noactive_1y',\n 'n1002_max_all_noactive_6m',\n 'n1002_avg_micro_noactive_all',\n 'n1000_count_n1000_0_micro_noactive_1y',\n 'n1004_max_all_noactive_all',\n 'n1000_count_n1000_0_micro_noactive_all',\n 'n1005_avg_all_noactive_1y',\n 'n1000_count_n1000_1_all_noactive_all',\n 'n1004_avg_micro_noactive_6m',\n 'n1005_avg_micro_noactive_all',\n 'n1006_min_all_noactive_all',\n 'n1005_min_all_noactive_all',\n 'Paymeanmfo_10_0',\n 'Paymeanmfo_10_1',\n 'Paymeanmfo_10_3',\n 'Paymeanmfo_10_4',\n 'Paymeanmfo_10_5',\n 'Paymeanmfo_10_6',\n 'Paymeanmfo_10_7',\n 'Paymeanmfo_10_8',\n 'Paymeanmfo_10_9']",
                                      "['DebtSignCalcLastPayout_cnt0_all_noactive_all',\n 'DebtFirstSum_max_min_all_noactive_1y',\n 'DebtFirstSum_max_min_micro_noactive_all',\n 'DebtSum_min_max_all_noactive_1y',\n 'DebtFirstSum_sum_max_all_noactive_6m',\n 'DebtSum_max_max_micro_noactive_6m',\n 'DebtSum_min_sum_micro_noactive_1y',\n 'DebtSum_min_avg_micro_noactive_6m',\n 'DebtPercentSum_sum_avg_all_noactive_all',\n 'DebtFirstSum_min_sum_all_noactive_1y',\n 'DebtOtherSum_min_sum_micro_noactive_6m',\n 'DebtSum_min_sum_all_noactive_all',\n 'DebtOtherSum_sum_max_all_noactive_1y',\n 'DebtOtherSum_avg_sum_all_noactive_all',\n 'DebtPercentSum_avg_max_micro_noactive_6m',\n 'DebtOtherSum_max_avg_all_noactive_1y',\n 'DebtOtherSum_max_avg_all_noactive_6m',\n 'DebtSum_sum_avg_all_noactive_all',\n 'DebtOtherSum_avg_max_all_noactive_6m',\n 'DebtPercentSum_sum_avg_micro_noactive_all',\n 'DebtFirstSum_min_min_all_noactive_all',\n 'debt_count_all_noactive_6m',\n 'DebtFirstSum_avg_sum_all_noactive_all',\n 'DebtPercentSum_max_avg_all_noactive_1y',\n 'DebtFirstSum_max_max_all_noactive_all',\n 'DebtPercentSum_avg_avg_micro_noactive_6m',\n 'DebtOtherSum_avg_avg_all_noactive_all',\n 'DebtFirstSum_min_max_micro_noactive_all',\n 'DebtPercentSum_max_max_micro_noactive_all',\n 'DebtSum_max_max_micro_noactive_all',\n 'DebtOtherSum_min_sum_micro_noactive_all',\n 'DebtSum_avg_avg_micro_noactive_all',\n 'DebtOtherSum_sum_avg_micro_noactive_6m',\n 'DebtOtherSum_avg_avg_micro_noactive_all',\n 'DebtFirstSum_avg_avg_all_noactive_all',\n 'DebtOtherSum_sum_avg_micro_noactive_1y',\n 'Debt_10_0',\n 'Debt_10_1',\n 'Debt_10_2',\n 'Debt_10_3',\n 'Debt_10_4',\n 'Debt_10_6',\n 'Debt_10_7',\n 'Debt_10_8',\n 'Debt_10_9']",
                                      "[ 'PaidOpSum_sum_max_micro_noactive_6m',\n 'PaidPercentSum_max_max_all_noactive_all',\n 'LastPayoutOtherSum_max_sum_micro_noactive_6m',\n 'PaidSum_max_sum_all_noactive_1y',\n 'PaidOtherSum_max_avg_micro_noactive_1y',\n 'PaidPercentSum_max_sum_micro_noactive_6m',\n 'LastPayoutOtherSum_max_avg_all_noactive_6m',\n 'LastPayoutOtherSum_min_avg_micro_noactive_all',\n 'LastPayoutOtherSum_max_avg_all_noactive_1y',\n 'PaidSum_min_avg_micro_noactive_all',\n 'PaidOpSum_min_max_micro_noactive_all',\n 'LastPayoutOtherSum_min_avg_all_noactive_all',\n 'LastPayoutPercentSum_avg_min_micro_noactive_1y',\n 'LastPayoutPercentSum_min_avg_micro_noactive_1y',\n 'Payments_count_all_noactive_all',\n 'PaidOtherSum_avg_sum_micro_noactive_6m',\n 'PaidOtherSum_max_max_all_noactive_all',\n 'OverdueDay_avg_max_all_noactive_1y',\n 'LastPayoutOpSum_max_avg_all_noactive_all',\n 'PaidSum_sum_avg_all_noactive_all',\n 'PaidPercentSum_max_max_all_noactive_6m',\n 'PaidOtherSum_avg_avg_all_noactive_1y',\n 'LastPayoutSum_avg_avg_micro_noactive_all',\n 'PaidOtherSum_sum_sum_micro_noactive_all',\n 'SizePaymentsTypeID_ohe1_avg_sum_micro_noactive_1y',\n 'SizePaymentsTypeID_ohe3_avg_sum_micro_noactive_1y',\n 'PaidOpSum_min_avg_micro_noactive_1y',\n 'DeadlineTypeID_ohe3_sum_sum_micro_noactive_6m',\n 'LastPayoutOpSum_min_sum_all_noactive_all',\n 'LastPayoutPercentSum_sum_max_micro_noactive_6m',\n 'PaidOtherSum_sum_sum_all_noactive_1y',\n 'LastPayoutOtherSum_avg_max_all_noactive_1y',\n 'LastPayoutSum_sum_max_all_noactive_6m',\n 'OverdueDay_min_max_all_noactive_all',\n 'PaidOpSum_max_max_all_noactive_1y',\n 'LastPayoutOtherSum_min_avg_micro_noactive_1y',\n 'LastPayoutPercentSum_min_max_all_noactive_1y',\n 'LastPayoutSum_max_max_micro_noactive_1y',\n 'LastPayoutOpSum_max_min_all_noactive_1y',\n 'PaidOtherSum_max_avg_all_noactive_all',\n 'LastPayoutSum_avg_avg_all_noactive_1y',\n 'LastPayoutOtherSum_min_max_all_noactive_6m',\n 'PaidOpSum_sum_max_all_noactive_6m',\n 'LastPayoutOpSum_min_min_micro_noactive_6m',\n 'OverdueDay_sum_sum_micro_noactive_6m',\n 'OverdueDay_sum_avg_all_noactive_all',\n 'LastPayoutSum_min_max_all_noactive_all',\n 'PaidPercentSum_sum_avg_all_noactive_1y',\n 'PaidOtherSum_min_max_all_noactive_6m',\n 'PaidPercentSum_min_max_all_noactive_1y',\n 'PaidPercentSum_sum_avg_micro_noactive_6m',\n 'PaidOpSum_max_avg_all_noactive_6m',\n 'LastPayoutOtherSum_min_sum_all_noactive_all',\n 'PaidOpSum_max_max_all_noactive_all',\n 'LastPayoutSum_min_max_all_noactive_1y',\n 'SizePaymentsTypeID_ohe2_avg_sum_all_noactive_all',\n 'OverdueDay_min_max_micro_noactive_all',\n 'PaidSum_min_avg_all_noactive_1y',\n 'PaidPercentSum_min_avg_micro_noactive_all',\n 'PaidOtherSum_max_avg_all_noactive_6m',\n 'OverdueDay_sum_avg_micro_noactive_all',\n 'PaidOtherSum_max_avg_micro_noactive_all',\n 'PaidPercentSum_avg_avg_all_noactive_all',\n 'Payments_10_1',\n 'Payments_10_2',\n 'Payments_10_3',\n 'Payments_10_4',\n 'Payments_10_5',\n 'Payments_10_6',\n 'Payments_10_7',\n 'Payments_10_8',\n 'Payments_10_9']"]}

# %%
X = []
ank_dop = ['ActivityType', 'Education', 'Gender', 'LoanPurpose', 'MaritalStatus', 'MonthlyIncome',
 'Post', 'InsurancePolicy', 'VerifiedByESIA', 'EMailVerified', 'RegisterSameFact', 'StoreName',
 'mobile', 'PingTreeLead', 'Bin', 'Bank', 'mask_person_addcontact', 'age','OrganizationPhone_group']

for i, row in enumerate(info_dict['Название таблицы']):
    table_name = info_dict['Название таблицы'][i]
    X.extend(eval(info_dict['оставшиеся столбцы'][i])) #формируем список окончательных фичей
    df.reset_index(inplace=True, drop=True) #для мерджа РСА фичей

    if table_name == 'Court' or table_name == 'JointDebtors':
        n = 2
    else:
        n = 10
    
    # считываем pickle файлы
    with open(f'Z:\\Скоринг –Олег\\Подготовка фичей\\новое\\После очистки\\{table_name}\\{table_name}_StandardScaler.pickle', 'rb') as scaler_file:
        scaler = pickle.load(scaler_file)

    with open(f'Z:\\Скоринг –Олег\\Подготовка фичей\\новое\\После очистки\\{table_name}\\{table_name}_pca_{n}.pickle', 'rb') as pca_file:
        pca = pickle.load(pca_file)
    

    # применяем метод РСА
    columns_to_pca = eval(info_dict['столбцы для РСА'][i])
    data_to_PCA = df[columns_to_pca].fillna(0).copy()
    data_pca = pd.DataFrame(pca.transform(scaler.transform(data_to_PCA)), columns=[f"{table_name}_{n}_{i}" for i in range(n)])
    df = pd.concat([df, data_pca], axis=1, ignore_index=False) 

out = df[X + ank_dop + ['Score', 'ScoringAmount']] #окончательный список фичей 
out
# Out:
#    A_sum_micro_noactive_all  len_str_sum_micro_noactive_6m  \
# 0                       0.0                           16.0
#
#    0_sum_all_noactive_all  2_sum_all_noactive_all  1_max_all_noactive_1y  \
# 0                    28.0                     4.0                    1.0
#
#    last_0_sum_micro_noactive_6m  0_avg_micro_noactive_all  \
# 0                           5.0                       1.0
#
#    len_str_max_micro_noactive_1y  len_str_avg_all_noactive_6m  \
# 0                            3.0                          1.0
#
#    last_dash_sum_all_noactive_1y  ...  StoreName    mobile  PingTreeLead  \
# 0                            0.0  ...  -0.000511 -0.000511      0.031686
#
#         Bin      Bank  mask_person_addcontact  age  OrganizationPhone_group  \
# 0  0.301484  0.241844               -0.000343   21                 0.008281
#
#    Score  ScoringAmount
# 0  500.0         5900.0
#
# [1 rows x 427 columns]

# %% [markdown]
# # Тест на модели

# %%
with open("C:\\Users\\e8\\Documents\\new_scoring_23\\models\\v2\\model_v2_7.pickle", "rb") as file:
    model = pickle.load(file)

# %%
'''out['score'] = model.predict_proba(out[model.feature_names_])[:,1]
out['score']'''
# Out:
# "out['score'] = model.predict_proba(out[model.feature_names_])[:,1]\nout['score']"

# %%
data = {"ActivityType":-0.0189360388,"Education":0.2065106512,"Gender":0.13771271,"LoanPurpose":-0.0205919074,"MaritalStatus":0.0738940108,"MonthlyIncome":0.0463071444,"Post":0.1558430287,"InsurancePolicy":0.1544362903,"VerifiedByESIA":0.003900833,"EMailVerified":-0.0003740975,"RegisterSameFact":0.0163741032,"StoreName":-0.0005111024,"mobile":-0.0005111024,"PingTreeLead":0.0316855385,"Bin":0.3014844384,"Bank":0.2418441118,"mask_person_addcontact":-0.0003428901,"age":21,"OrganizationPhone_group":0.0082812403,"ScoringAmount":2000.0,"Score":500.0,"A_sum_micro_noactive_all":0.0,"len_str_sum_micro_noactive_6m":16.0,"0_sum_all_noactive_all":28.0,"2_sum_all_noactive_all":4.0,"1_max_all_noactive_1y":1.0,"last_0_sum_micro_noactive_6m":5.0,"0_avg_micro_noactive_all":1.0,"len_str_max_micro_noactive_1y":3.0,"len_str_avg_all_noactive_6m":1.0,"last_dash_sum_all_noactive_1y":0.0,"C_avg_micro_noactive_all":9.0,"2_sum_all_noactive_6m":3.0,"C_max_all_noactive_6m":2.0,"last_C_sum_all_noactive_all":14.0,"S_max_all_noactive_all":0.0,"len_str_sum_all_noactive_all":50.0,"C_avg_micro_noactive_6m":0.0,"dash_max_all_noactive_1y":0.0,"A_max_all_noactive_all":0.0,"len_str_max_all_noactive_all":7.0,"0_avg_all_noactive_1y":1.0,"dash_max_micro_noactive_all":0.0,"len_str_avg_micro_noactive_all":2.0,"0_max_all_noactive_all":4.0,"1_max_all_noactive_all":1.0,"len_str_avg_all_noactive_1y":1.0,"C_max_all_noactive_all":20.0,"len_str_max_micro_noactive_all":7.0,"0_max_all_noactive_1y":2.0,"dash_max_micro_noactive_6m":0.0,"2_max_micro_noactive_all":1.0,"len_str_max_all_noactive_6m":3.0,"2_max_all_noactive_all":1.0,"1_max_micro_noactive_all":1.0,"0_avg_all_noactive_all":1.0,"C_max_micro_noactive_1y":2.0,"0_max_micro_noactive_1y":2.0,"dash_sum_micro_noactive_all":0.0,"0_max_all_noactive_6m":2.0,"3_max_all_noactive_all":1.0,"len_str_max_micro_noactive_6m":3.0,"0_max_micro_noactive_all":4.0,"pay_discipline_10_3":1.5872954897,"pay_discipline_10_4":0.5662546085,"pay_discipline_10_5":-0.4112223633,"pay_discipline_10_6":1.7860283721,"pay_discipline_10_7":0.0371586311,"pay_discipline_10_8":-0.2345283957,"pay_discipline_10_9":0.5061718859,"PaymentTerms_count_all_noactive_6m":10.0,"Regularity_ohe99_sum_sum_all_noactive_1y":1.0,"NextPayoutSum_sum_sum_all_noactive_all":46800.0,"Regularity_ohe1_sum_sum_micro_noactive_all":0.0,"Regularity_ohe3_avg_max_all_noactive_6m":0.0,"NextPayoutSum_avg_max_all_noactive_1y":21600.0,"NextPayoutSum_max_avg_micro_noactive_6m":4680.0,"PercentNextPayoutSum_min_avg_all_noactive_6m":1790.0,"NextPayoutSum_sum_max_micro_noactive_6m":21600.0,"PercentNextPayoutSum_avg_max_micro_noactive_1y":5702.4,"NextPayoutSum_max_avg_all_noactive_1y":4680.0,"Regularity_ohe3_avg_sum_all_noactive_6m":0.0,"PercentNextPayoutSum_avg_sum_all_noactive_all":11370.0,"NextPayoutSum_avg_avg_all_noactive_all":2752.941176,"Regularity_ohe2_sum_sum_micro_noactive_6m":0.0,"Regularity_ohe2_sum_max_micro_noactive_all":0.0,"Regularity_ohe3_sum_sum_all_noactive_all":0.0,"Regularity_ohe3_avg_sum_micro_noactive_1y":0.0,"NextPayoutSum_sum_max_all_noactive_all":21600.0,"PercentNextPayoutSum_sum_max_all_noactive_all":5702.4,"PercentNextPayoutSum_min_avg_all_noactive_all":1624.285714,"NextPayoutSum_min_max_all_noactive_6m":21600.0,"payment_terms_10_1":1.3369248887,"payment_terms_10_3":-0.5727619737,"payment_terms_10_4":-1.2394566322,"payment_terms_10_6":-0.8121712834,"payment_terms_10_7":-0.4970326917,"payment_terms_10_8":-0.3456895723,"payment_terms_10_9":0.0042478827,"ContractAmountCurrencyIsRUR_sum_all_noactive_all":22.0,"ContractAmountSum_avg_all_noactive_1y":9137.4,"ContractAmountSum_avg_all_noactive_all":8194.298181,"ContractAmountSum_min_all_noactive_all":2200.0,"ContractAmountSum_max_all_noactive_all":21600.0,"ContractAmountSum_max_micro_noactive_6m":21600.0,"ContractAmountSum_max_all_noactive_6m":21600.0,"ContractAmountSum_sum_all_noactive_1y":91374.0,"ContractAmountSum_avg_micro_noactive_all":8194.298181,"ContractAmountSum_max_micro_noactive_all":21600.0,"ContractAmountSum_min_all_noactive_6m":3200.0,"ContractAmountSum_sum_all_noactive_all":180274.56,"ContractAmount_10_2":-0.0817527103,"ContractAmount_10_3":0.1042728537,"ContractAmount_10_5":0.0494028576,"ContractAmount_10_6":-0.0907735272,"ContractAmount_10_7":0.1129538284,"ContractAmount_10_8":-0.0865291229,"ContractAmount_10_9":0.0332063079,"Delay90_sum_all_noactive_all":0.0,"CredMaxOverdue_max_all_noactive_all":14200.56,"Delay30_max_all_noactive_all":1.0,"CredMaxOverdue_max_all_noactive_6m":9000.0,"CredMaxOverdue_avg_all_noactive_all":1480.661818,"Delay30_sum_all_noactive_1y":3.0,"CredMaxOverdue_sum_all_noactive_6m":18374.0,"DelayMore_sum_all_noactive_all":1.0,"CredMaxOverdue_max_all_noactive_1y":9000.0,"CredMaxOverdue_avg_all_noactive_6m":1837.4,"Delay5_sum_all_noactive_all":0.0,"Delay60_sum_all_noactive_all":0.0,"CredMaxOverdue_avg_all_noactive_1y":1837.4,"Summary_10_0":-0.1191023912,"Summary_10_1":1.0484511204,"Summary_10_2":0.2343762596,"Summary_10_3":-0.1593001429,"Summary_10_4":0.1870701216,"Summary_10_5":-0.2747769603,"Summary_10_6":0.0243579957,"Summary_10_7":-0.2617304603,"Summary_10_8":0.3102053839,"Summary_10_9":-0.1910458613,"ChangeType_ohe3_sum_max_all_noactive_6m":np.NaN,"ChangeSign_sum_sum_micro_noactive_6m":np.NaN,"ChangeType_ohe1_sum_max_all_noactive_1y":np.NaN,"ChangeSign_sum_max_all_noactive_all":5.0,"ContractChanges_count_micro_noactive_all":3.0,"ChangeType_ohe3_sum_min_micro_noactive_1y":np.NaN,"ChangeSign_sum_avg_all_noactive_6m":np.NaN,"ChangeType_ohe3_sum_avg_micro_noactive_1y":np.NaN,"ChangeType_ohe3_sum_avg_all_noactive_all":2.0,"ChangeType_ohe3_sum_max_all_noactive_1y":np.NaN,"ChangeSign_sum_avg_micro_noactive_all":2.0,"ChangeType_ohe3_sum_max_micro_noactive_all":5.0,"ContractChanges_10_3":0.9253390645,"ContractChanges_10_4":1.0736361785,"ContractChanges_10_5":0.9201034779,"ContractChanges_10_6":-0.5004794452,"ContractChanges_10_7":-0.1518178646,"ContractChanges_10_8":0.1132489511,"ContractChanges_10_9":-0.0216950302,"CourtDisputeCase_oheNULL_sum_micro_noactive_1y":10.0,"CourtSign_oheNULL_sum_micro_noactive_all":22.0,"Court_2_1":0.1636009774,"DealCredOwnerTypeIsNull_sum_micro_noactive_1y":4.0,"DealPurposeID_ohe99_sum_micro_noactive_1y":6.0,"DealDays_avg_micro_noactive_6m":25.0,"DealDays_min_all_noactive_all":3.0,"Deal_count_all_noactive_all":22.0,"DealDays_sum_all_noactive_1y":255.0,"DealDays_max_micro_noactive_all":125.0,"DealPurposeID_ohe15_sum_all_noactive_all":0.0,"DealDays_sum_all_noactive_all":833.0,"DealDays_max_all_noactive_6m":33.0,"DealDays_max_micro_noactive_6m":33.0,"DealDays_avg_all_noactive_6m":25.0,"DealDays_avg_all_noactive_all":37.0,"DealType_ohe1_sum_all_noactive_1y":0.0,"DealType_ohe5_sum_all_noactive_all":0.0,"Deal_10_0":-1.9254850359,"Deal_10_1":-0.304625436,"Deal_10_2":0.0426328074,"Deal_10_3":0.2534164546,"Deal_10_4":0.0491254928,"Deal_10_5":0.1282109099,"Deal_10_6":0.1665392783,"Deal_10_7":0.1202804474,"Deal_10_8":-0.0187037335,"Deal_10_9":-0.0310664618,"DebtCurrentOpSum_max_min_all_noactive_6m":4000.0,"DebtCurrentPercentSum_max_avg_all_noactive_1y":781.0,"DebtCurrentOtherSum_avg_avg_all_noactive_1y":0.0,"DebtCurrentDebtSum_sum_avg_micro_noactive_6m":12481.0,"DebtCurrentDebtSum_avg_min_micro_noactive_1y":4000.0,"DebtCurrentDebtSum_min_max_micro_noactive_all":21600.0,"DebtCurrentPercentSum_min_avg_micro_noactive_all":781.0,"DebtCurrentOtherSum_min_max_all_noactive_all":0.0,"DebtCurrentPercentSum_min_max_micro_noactive_all":3124.0,"DebtCurrentOpSum_avg_min_all_noactive_all":4000.0,"DebtCurrentOpSum_max_sum_all_noactive_1y":46800.0,"DebtCurrentOpSum_avg_max_all_noactive_6m":21600.0,"DebtCurrentPercentSum_max_max_all_noactive_1y":3124.0,"DebtCurrentOtherSum_max_max_all_noactive_6m":0.0,"DebtCurrentDebtSum_max_max_all_noactive_all":21600.0,"DebtCurrentDebtSum_min_avg_all_noactive_1y":12481.0,"DebtCurrentOtherSum_sum_avg_all_noactive_6m":0.0,"DebtCurrentOtherSum_min_max_all_noactive_1y":0.0,"DebtCurrentOtherSum_avg_avg_all_noactive_all":0.0,"DebtCurrent_10_0":-0.5182129586,"DebtCurrent_10_1":-0.3098667693,"DebtCurrent_10_5":0.1824481153,"DebtCurrent_10_6":0.0013292721,"DebtCurrent_10_7":-0.044436136,"DebtCurrent_10_8":-0.0452695979,"DebtCurrent_10_9":0.0163924073,"ContractEndDateDaysFromDeal_min_all_noactive_all":3.0,"ContractEndDateDaysFromDeal_avg_micro_noactive_all":45.0,"ContractEndReason_ohe1_sum_micro_noactive_6m":5.0,"FullCostSum_max_all_noactive_6m":22940.0,"FullCostSum_avg_all_noactive_1y":5157.564,"AveragePaymentSum_sum_all_noactive_6m":38897.0,"FullCostSum_sum_micro_noactive_1y":51575.64,"AveragePaymentSum_avg_all_noactive_6m":4321.888888,"FullCostPercent_min_micro_noactive_1y":219.0,"ContractEndDateDaysFromDeal_max_all_noactive_all":149.0,"FullCostPercent_avg_all_noactive_6m":284.7,"ContractEndReason_ohe1_sum_all_noactive_all":15.0,"FullCostSum_min_all_noactive_1y":76.8,"ContractEndReason_oheNULL_sum_all_noactive_all":5.0,"AveragePaymentSum_max_all_noactive_1y":17124.0,"AveragePaymentSum_max_all_noactive_6m":17124.0,"FullCostSum_avg_micro_noactive_1y":5157.564,"FullCostSum_sum_all_noactive_1y":51575.64,"FullCostSum_max_all_noactive_all":22940.0,"ContractEndDateDaysFromDeal_sum_all_noactive_all":781.0,"FullCostPercent_min_all_noactive_all":219.0,"ContractEndDateDaysFromDeal_max_all_noactive_1y":40.0,"FullCostSum_max_micro_noactive_1y":22940.0,"CredStartDebtDaysFromDeal_sum_all_noactive_all":0.0,"AveragePaymentSum_max_micro_noactive_all":17124.0,"FullCostPercent_min_micro_noactive_all":219.0,"FullCostSum_avg_all_noactive_all":4191.24647,"CredStartDebtDaysFromDeal_max_all_noactive_1y":0.0,"ContractEndDateDaysFromDeal_max_micro_noactive_all":149.0,"AveragePaymentSum_avg_all_noactive_all":2431.0625,"ContractEndDateDaysFromDeal_max_all_noactive_6m":40.0,"AveragePaymentSum_avg_micro_noactive_all":2431.0625,"AveragePaymentSum_sum_all_noactive_all":38897.0,"ContractEndDateDaysFromDeal_avg_all_noactive_all":45.0,"CredStartDebtDaysFromDeal_max_all_noactive_all":0.0,"FullCostPercent_avg_micro_noactive_all":324.320454,"FullCostPercent_min_all_noactive_1y":219.0,"AveragePaymentSum_avg_all_noactive_1y":4321.888888,"ContractEndDateDaysFromDeal_sum_micro_noactive_all":781.0,"FullCostPercent_10_1":-0.1462877248,"FullCostPercent_10_2":1.4017758439,"FullCostPercent_10_3":0.303733017,"FullCostPercent_10_4":0.6179533781,"FullCostPercent_10_5":-0.5765215712,"FullCostPercent_10_6":0.4278043596,"FullCostPercent_10_7":0.2685562149,"FullCostPercent_10_8":-0.9981521066,"FullCostPercent_10_9":0.0440409705,"JointDebtors_count_micro_noactive_1y":6.0,"JointDebtors_count_all_noactive_all":14.0,"JointDebtors_2_1":0.0943455473,"n1007_avg_all_noactive_all":17.0,"n1002_max_micro_noactive_1y":21600.0,"n1005_avg_micro_noactive_6m":292.0,"n1004_sum_all_noactive_6m":6.0,"n1002_sum_micro_noactive_1y":65300.0,"n1005_min_all_noactive_6m":292.0,"n1006_max_micro_noactive_1y":23001.67,"n1006_avg_micro_noactive_6m":13691.8,"n1007_max_all_noactive_all":17.0,"n1001_min_all_noactive_all":np.NaN,"n1002_avg_all_noactive_all":13060.0,"n1001_max_all_noactive_1y":np.NaN,"n1006_max_micro_noactive_all":23001.67,"n1006_max_all_noactive_1y":23001.67,"n1002_min_all_noactive_1y":4000.0,"n1002_sum_all_noactive_all":65300.0,"n1005_min_micro_noactive_all":292.0,"n1000_count_n1000_2_all_noactive_all":0.0,"n1004_avg_all_noactive_1y":1.2,"n1006_min_micro_noactive_6m":4973.33,"n1003_sum_micro_noactive_6m":0.0,"n1004_max_all_noactive_1y":2.0,"n1004_avg_micro_noactive_all":1.2,"n1003_avg_all_noactive_all":0.0,"n1002_max_all_noactive_1y":21600.0,"n1002_max_all_noactive_6m":21600.0,"n1002_avg_micro_noactive_all":13060.0,"n1000_count_n1000_0_micro_noactive_1y":5.0,"n1004_max_all_noactive_all":2.0,"n1000_count_n1000_0_micro_noactive_all":17.0,"n1005_avg_all_noactive_1y":292.0,"n1000_count_n1000_1_all_noactive_all":0.0,"n1004_avg_micro_noactive_6m":1.2,"n1005_avg_micro_noactive_all":292.0,"n1006_min_all_noactive_all":4973.33,"n1005_min_all_noactive_all":292.0,"Paymeanmfo_10_0":-0.1635160532,"Paymeanmfo_10_1":-1.0202991708,"Paymeanmfo_10_3":0.1673180045,"Paymeanmfo_10_4":0.2012956796,"Paymeanmfo_10_5":0.7556291733,"Paymeanmfo_10_6":0.6767886311,"Paymeanmfo_10_7":-0.2823687398,"Paymeanmfo_10_8":-0.7254377523,"Paymeanmfo_10_9":-0.036879255,"DebtSignCalcLastPayout_cnt0_all_noactive_all":22.0,"DebtFirstSum_max_min_all_noactive_1y":3200.0,"DebtFirstSum_max_min_micro_noactive_all":2200.0,"DebtSum_min_max_all_noactive_1y":21600.0,"DebtFirstSum_sum_max_all_noactive_6m":21600.0,"DebtSum_max_max_micro_noactive_6m":21600.0,"DebtSum_min_sum_micro_noactive_1y":49924.0,"DebtSum_min_avg_micro_noactive_6m":5547.111111,"DebtPercentSum_sum_avg_all_noactive_all":148.761904,"DebtFirstSum_min_sum_all_noactive_1y":72874.0,"DebtOtherSum_min_sum_micro_noactive_6m":0.0,"DebtSum_min_sum_all_noactive_all":49924.0,"DebtOtherSum_sum_max_all_noactive_1y":0.0,"DebtOtherSum_avg_sum_all_noactive_all":0.0,"DebtPercentSum_avg_max_micro_noactive_6m":3124.0,"DebtOtherSum_max_avg_all_noactive_1y":0.0,"DebtOtherSum_max_avg_all_noactive_6m":0.0,"DebtSum_sum_avg_all_noactive_all":2377.333333,"DebtOtherSum_avg_max_all_noactive_6m":0.0,"DebtPercentSum_sum_avg_micro_noactive_all":148.761904,"DebtFirstSum_min_min_all_noactive_all":2200.0,"debt_count_all_noactive_6m":10.0,"DebtFirstSum_avg_sum_all_noactive_all":161774.56,"DebtPercentSum_max_avg_all_noactive_1y":347.111111,"DebtFirstSum_max_max_all_noactive_all":21600.0,"DebtPercentSum_avg_avg_micro_noactive_6m":347.111111,"DebtOtherSum_avg_avg_all_noactive_all":0.0,"DebtFirstSum_min_max_micro_noactive_all":21600.0,"DebtPercentSum_max_max_micro_noactive_all":3124.0,"DebtSum_max_max_micro_noactive_all":21600.0,"DebtOtherSum_min_sum_micro_noactive_all":0.0,"DebtSum_avg_avg_micro_noactive_all":2377.333333,"DebtOtherSum_sum_avg_micro_noactive_6m":0.0,"DebtOtherSum_avg_avg_micro_noactive_all":0.0,"DebtFirstSum_avg_avg_all_noactive_all":7703.550476,"DebtOtherSum_sum_avg_micro_noactive_1y":0.0,"Debt_10_0":-1.2024437255,"Debt_10_1":0.0022881978,"Debt_10_2":-0.1506005007,"Debt_10_3":0.1752858664,"Debt_10_4":0.3762053208,"Debt_10_6":0.1374617717,"Debt_10_7":-0.0587055474,"Debt_10_8":-0.2258512492,"Debt_10_9":-0.1700102123,"PaidOpSum_sum_max_micro_noactive_6m":9000.0,"PaidPercentSum_max_max_all_noactive_all":20569.53,"LastPayoutOtherSum_max_sum_micro_noactive_6m":17.15,"PaidSum_max_sum_all_noactive_1y":32230.46,"PaidOtherSum_max_avg_micro_noactive_1y":2.448571,"PaidPercentSum_max_sum_micro_noactive_6m":6139.32,"LastPayoutOtherSum_max_avg_all_noactive_6m":4.2875,"LastPayoutOtherSum_min_avg_micro_noactive_all":74.848,"LastPayoutOtherSum_max_avg_all_noactive_1y":4.2875,"PaidSum_min_avg_micro_noactive_all":9418.645263,"PaidOpSum_min_max_micro_noactive_all":16300.0,"LastPayoutOtherSum_min_avg_all_noactive_all":74.848,"LastPayoutPercentSum_avg_min_micro_noactive_1y":76.8,"LastPayoutPercentSum_min_avg_micro_noactive_1y":1127.862,"Payments_count_all_noactive_all":22.0,"PaidOtherSum_avg_sum_micro_noactive_6m":17.14,"PaidOtherSum_max_max_all_noactive_all":731.32,"OverdueDay_avg_max_all_noactive_1y":0.0,"LastPayoutOpSum_max_avg_all_noactive_all":6662.654117,"PaidSum_sum_avg_all_noactive_all":9418.645263,"PaidPercentSum_max_max_all_noactive_6m":2664.0,"PaidOtherSum_avg_avg_all_noactive_1y":2.448571,"LastPayoutSum_avg_avg_micro_noactive_all":6866.414761,"PaidOtherSum_sum_sum_micro_noactive_all":748.46,"SizePaymentsTypeID_ohe1_avg_sum_micro_noactive_1y":5.0,"SizePaymentsTypeID_ohe3_avg_sum_micro_noactive_1y":4.0,"PaidOpSum_min_avg_micro_noactive_1y":3724.857142,"DeadlineTypeID_ohe3_sum_sum_micro_noactive_6m":0.0,"LastPayoutOpSum_min_sum_all_noactive_all":113265.12,"LastPayoutPercentSum_sum_max_micro_noactive_6m":2664.0,"PaidOtherSum_sum_sum_all_noactive_1y":17.14,"LastPayoutOtherSum_avg_max_all_noactive_1y":17.15,"LastPayoutSum_sum_max_all_noactive_6m":11664.0,"OverdueDay_min_max_all_noactive_all":0.0,"PaidOpSum_max_max_all_noactive_1y":9000.0,"LastPayoutOtherSum_min_avg_micro_noactive_1y":4.2875,"LastPayoutPercentSum_min_max_all_noactive_1y":2664.0,"LastPayoutSum_max_max_micro_noactive_1y":11664.0,"LastPayoutOpSum_max_min_all_noactive_1y":3200.0,"PaidOtherSum_max_avg_all_noactive_all":53.461428,"LastPayoutSum_avg_avg_all_noactive_1y":3525.606666,"LastPayoutOtherSum_min_max_all_noactive_6m":17.15,"PaidOpSum_sum_max_all_noactive_6m":9000.0,"LastPayoutOpSum_min_min_micro_noactive_6m":3200.0,"OverdueDay_sum_sum_micro_noactive_6m":0.0,"OverdueDay_sum_avg_all_noactive_all":0.0,"LastPayoutSum_min_max_all_noactive_all":28871.32,"PaidPercentSum_sum_avg_all_noactive_1y":877.045714,"PaidOtherSum_min_max_all_noactive_6m":17.14,"PaidPercentSum_min_max_all_noactive_1y":2664.0,"PaidPercentSum_sum_avg_micro_noactive_6m":877.045714,"PaidOpSum_max_avg_all_noactive_6m":3724.857142,"LastPayoutOtherSum_min_sum_all_noactive_all":748.48,"PaidOpSum_max_max_all_noactive_all":16300.0,"LastPayoutSum_min_max_all_noactive_1y":11664.0,"SizePaymentsTypeID_ohe2_avg_sum_all_noactive_all":1.0,"OverdueDay_min_max_micro_noactive_all":0.0,"PaidSum_min_avg_all_noactive_1y":4604.351428,"PaidPercentSum_min_avg_micro_noactive_all":3769.660714,"PaidOtherSum_max_avg_all_noactive_6m":2.448571,"OverdueDay_sum_avg_micro_noactive_all":0.0,"PaidOtherSum_max_avg_micro_noactive_all":53.461428,"PaidPercentSum_avg_avg_all_noactive_all":3769.660714,"Payments_10_1":-0.0984890503,"Payments_10_2":-0.1352705978,"Payments_10_3":-0.3378406388,"Payments_10_4":0.6916827741,"Payments_10_5":-0.3541822834,"Payments_10_6":-0.9226093238,"Payments_10_7":0.6307697178,"Payments_10_8":0.1874369445,"Payments_10_9":0.0984219901}
df1 = pd.json_normalize(data)

# %%
df1
# Out:
#    ActivityType  Education    Gender  LoanPurpose  MaritalStatus  \
# 0     -0.018936   0.206511  0.137713    -0.020592       0.073894
#
#    MonthlyIncome      Post  InsurancePolicy  VerifiedByESIA  EMailVerified  \
# 0       0.046307  0.155843         0.154436        0.003901      -0.000374
#
#    ...  PaidPercentSum_avg_avg_all_noactive_all  Payments_10_1  Payments_10_2  \
# 0  ...                              3769.660714      -0.098489      -0.135271
#
#    Payments_10_3  Payments_10_4  Payments_10_5  Payments_10_6  Payments_10_7  \
# 0      -0.337841       0.691683      -0.354182      -0.922609        0.63077
#
#    Payments_10_8  Payments_10_9
# 0       0.187437       0.098422
#
# [1 rows x 427 columns]

# %%
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500

# %%
df3 = pd.concat([out,df1])

# %%
df3
# Out:
#    A_sum_micro_noactive_all  len_str_sum_micro_noactive_6m  \
# 0                       0.0                           16.0
# 0                       0.0                           16.0
#
#    0_sum_all_noactive_all  2_sum_all_noactive_all  1_max_all_noactive_1y  \
# 0                    28.0                     4.0                    1.0
# 0                    28.0                     4.0                    1.0
#
#    last_0_sum_micro_noactive_6m  0_avg_micro_noactive_all  \
# 0                           5.0                       1.0
# 0                           5.0                       1.0
#
#    len_str_max_micro_noactive_1y  len_str_avg_all_noactive_6m  \
# 0                            3.0                          1.0
# 0                            3.0                          1.0
#
#    last_dash_sum_all_noactive_1y  C_avg_micro_noactive_all  \
# 0                            0.0                       9.0
# 0                            0.0                       9.0
#
# ...

# %%
df3['ScoringAmount'] = 5000

# %%
#df3['InsurancePolicy'] = 0.15444

# %%
model.predict_proba(df3[model.feature_names_])[:,0]
# Out:
# array([0.25946052, 0.25946052])

# %%
dd = df3.T

# %%
dd.columns = ['1','2']

# %%
dd['1'] = round(dd['1'], 5)
dd['2'] = round(dd['2'], 5)

# %%
dd['flag'] = np.where(dd['1'] != dd['2'], 1, 0)

# %%
dd[dd['flag'] == 1]
# Out:
#                                             1   2  flag
# ChangeType_ohe3_sum_max_all_noactive_6m   NaN NaN     1
# ChangeSign_sum_sum_micro_noactive_6m      NaN NaN     1
# ChangeType_ohe1_sum_max_all_noactive_1y   NaN NaN     1
# ChangeType_ohe3_sum_min_micro_noactive_1y NaN NaN     1
# ChangeSign_sum_avg_all_noactive_6m        NaN NaN     1
# ChangeType_ohe3_sum_avg_micro_noactive_1y NaN NaN     1
# ChangeType_ohe3_sum_max_all_noactive_1y   NaN NaN     1
# n1001_min_all_noactive_all                NaN NaN     1
# n1001_max_all_noactive_1y                 NaN NaN     1
